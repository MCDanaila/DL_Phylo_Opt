# %%
from Bio.Align import AlignInfo
import logging

from Tools import PhyML
from Utils import tree_functions
from Utils.defs_PhyAI import *
from Utils.utils import init_commandline_logger

logger = logging.getLogger('PIP Likelyhood main script')
init_commandline_logger(logger)

# %%
import ete3

def validate_input(msa_file, user_tree_file):
	"""
	:param msa_file: the path to an MSA file, one of biopython's formats
	:param user_tree_file: (optional) the path to a user tree file, if fixed tree was desired
	:return: a biopython object of the msa and an ete3 object of the tree if exists
	"""

	# identify format and retrieve all MSAs
	for aln_format in ["clustal", "emboss", "fasta", "fasta-m10", "ig", "maf", "mauve", "nexus", "phylip-relaxed", "phylip-sequential", "stockholm"]:
		try:
			msa_obj = AlignIO.read(msa_file, format=aln_format)
			logger.info("The MSA file is format: " + aln_format)
			break
		except Exception:
			msa_obj = None
	if msa_obj is None:
		logger.error("Error occured: the input file is not a valid alignmnet in a supported format.\n"
		             "Please verify that all sequences are at the same length and that the input format is correct.")

	# validate MSA characters
	msa_info = AlignInfo.SummaryInfo(msa_obj)
	aln_letters = msa_info._get_all_letters()
	for let in aln_letters:
		if not (let.lower() in "acgt-"):
			logger.warning("There are characters that are not nucleotides or gaps in your input MSA.")
			break

	# validate tree file in Newick format and suits the msa
	tree_obj = None
	if user_tree_file:
		try:
			with open(user_tree_file) as fpr:
				tree_obj = tree_functions.get_newick_tree(fpr.read().strip())
		except:
			logger.error("Tree file is invalid. Please verify that it's in Newick format.")
		print(tree_obj)
		# assert that the tree matches the corresponding MSA
		leaves = sorted([node.name for node in tree_obj.get_leaves()])
		seq_names = sorted([rec.id for rec in msa_obj])
		if len(leaves) != len(seq_names) or (not all(x == y for x,y  in zip(seq_names,leaves))):
			logger.error("The tips of the tree and the MSA sequences names do not match")

	return msa_obj

# %%
#for folder_name in os.listdir(TEST_DATA_PATH):
folder_name = '8'
CWD = TEST_DATA_PATH + folder_name
orig_msa_file = CWD + '/real_msa.phy'
run_id = DEFAULT_MODEL + "_" + folder_name
stats_file, tree_file = PhyML.run_phyml(orig_msa_file, DEFAULT_MODEL, run_id=run_id)
msa_obj = validate_input(orig_msa_file, tree_file)
# Out:
# INFO - Running PhyML: base_model='GTR' pinv=False gamma=False run_id='GTR_8'
# INFO - Running PhyML: execution_tags='-m 012345 -f m -v 0 -c 1 -o tlr -d nt -n 1 -b 0 --no_memory_check --run_id GTR_8'
#
#
#
#
#
#
#                                  ..........................
#  ooooooooooooooooooooooooooooo        CURRENT SETTINGS        ooooooooooooooooooooooooooooooooooo
#                                  ..........................
#
#                 . Sequence filename:				 real_msa.phy
#                 . Data type:					 dna
#                 . Alphabet size:				 4
#                 . Sequence format:				 interleaved
#                 . Number of data sets:				 1
#                 . Nb of bootstrapped data sets:			 0
#                 . Model name:					 Custom
#                 . Proportion of invariable sites:		 0.000000
#                 . Number of subst. rate categs:			 1
#                 . Nucleotide equilibrium frequencies:		 ML
#                 . Optimise tree topology:			 yes
#                 . Tree topology search:				 NNIs
#                 . Starting tree:				 BioNJ
#                 . Add random input tree:			 no
#                 . Optimise branch lengths:			 yes
#                 . Optimise substitution model parameters:	 yes
#                 . Run ID:					 GTR_8
#                 . Random seed:					 1694794090
#                 . Subtree patterns aliasing:			 no
#                 . Version:					 20120412
#
#  oooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooo
#
#
#
# . 403 patterns found (out of a total of 636 sites).
#
# . 141 sites without polymorphism (22.17%).
#
# . Computing pairwise distances...
#
# . Building BioNJ tree...
# . Refining the input tree...
#
# . Maximizing likelihood (using NNI moves)...
#
# . (    0 sec) [     -4659.9793] [GTR parameters     ]
# . (    0 sec) [     -4659.7586] [Nucleotide freqs.  ]
# . (    0 sec) [     -4659.7586] [Topology           ][# nnis=  1]
# . (    0 sec) [     -4658.7357] [Topology           ][# nnis=  0]
# . (    0 sec) [     -4656.9161] [Topology           ][# nnis=  0]
# . (    0 sec) [     -4656.3269] [Topology           ]
# . (    0 sec) [     -4656.1891] [GTR parameters     ]
# . (    0 sec) [     -4656.1693] [Nucleotide freqs.  ]
# . (    0 sec) [     -4656.1693] [Topology           ][# nnis=  0]
# . (    0 sec) [     -4655.7808] [Topology           ][# nnis=  0]
# . (    0 sec) [     -4655.5345] [Topology           ]
# . (    0 sec) [     -4655.5345] [Branch lengths     ]
# . (    0 sec) [     -4655.2728] [GTR parameters     ]
# . (    0 sec) [     -4655.2705] [Nucleotide freqs.  ]
# . (    0 sec) [     -4655.2705] [Branch lengths     ]
# . (    0 sec) [     -4655.1545] [GTR parameters     ]
# . (    0 sec) [     -4655.1532] [Nucleotide freqs.  ]
# . (    0 sec) [     -4655.1532] [Branch lengths     ]
# . (    0 sec) [     -4655.0904] [GTR parameters     ]
# . (    0 sec) [     -4655.0903] [Nucleotide freqs.  ]
# . (    0 sec) [     -4655.0903] [Branch lengths     ]
# . (    0 sec) [     -4655.0540] [GTR parameters     ]
# . (    0 sec) [     -4655.0538] [Nucleotide freqs.  ]
# . (    0 sec) [     -4655.0538] [Branch lengths     ]
# . (    0 sec) [     -4655.0335] [GTR parameters     ]
# . (    0 sec) [     -4655.0335] [Nucleotide freqs.  ]
# . (    0 sec) [     -4655.0335] [Branch lengths     ]
# . (    0 sec) [     -4655.0218] [GTR parameters     ]
# . (    0 sec) [     -4655.0218] [Nucleotide freqs.  ]
# . (    0 sec) [     -4655.0218] [Branch lengths     ]
# . (    0 sec) [     -4655.0152] [GTR parameters     ]
# . (    0 sec) [     -4655.0152] [Nucleotide freqs.  ]
# . (    0 sec) [     -4655.0152] [Branch lengths     ]
# . (    0 sec) [     -4655.0114] [GTR parameters     ]
# . (    0 sec) [     -4655.0113] [Nucleotide freqs.  ]
# . (    0 sec) [     -4655.0113] [Branch lengths     ]
# . (    0 sec) [     -4655.0092] [GTR parameters     ]
# . (    0 sec) [     -4655.0092] [Nucleotide freqs.  ]
# . (    0 sec) [     -4655.0092] [Branch lengths     ]
# . (    0 sec) [     -4655.0079] [GTR parameters     ]
# . (    0 sec) [     -4655.0079] [Nucleotide freqs.  ]
# . (    0 sec) [     -4655.0079] [Branch lengths     ]
# . (    0 sec) [     -4655.0072] [GTR parameters     ]
# . (    0 sec) [     -4655.0072] [Nucleotide freqs.  ]
# . (    0 sec) [     -4655.0072] [GTR parameters     ]
# . (    0 sec) [     -4655.0072] [Nucleotide freqs.  ]
#
# . Checking for NNIs, optimizing five branches...
#
#
#
# . Log likelihood of the current tree: -4655.007225.
#
# . Printing the most likely tree in file 'real_msa.phy_phyml_tree_GTR_8.txt'...
#
# . Time used 0h0m0s
#
# oooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooo
# 2023-09-15 18:08:11,007 - PIP Likelyhood main script - INFO - The MSA file is format: phylip-relaxed
#
#    /-Sp002
#   |
# --|--Sp003
#   |
#   |   /-Sp000
#    \-|
#      |   /-Sp001
#       \-|
#         |   /-Sp004
#          \-|
#            |   /-Sp006
#             \-|
#               |   /-Sp007
#                \-|
#                   \-Sp005

# %%
orig_tree_obj = tree_functions.get_phylo_tree(tree_file, orig_msa_file)
orig_tree_obj.get_tree_root().name = ROOTLIKE_NAME
print(orig_tree_obj.get_ascii(attributes=["name", "dist"]))
# Out:
#                      /-Sp003, 0.17093226
#               /N1, 0.0
#              |      |              /-Sp000, 0.88588667
#              |       \N4, 0.12633891
#              |                    |              /-Sp001, 0.21256585
#              |                     \N6, 0.18046101
#              |                                  |              /-Sp004, 0.48003642
# -ROOT_LIKE, 0.0                                  \N8, 0.11471175
#              |                                                |               /-Sp006, 0.01327609
#              |                                                 \N10, 0.59284149
#              |                                                               |               /-Sp007, 0.13766375
#              |                                                                \N12, 0.04863679
#              |                                                                               \-Sp005, 0.12854009
#              |
#               \-Sp002, 0.11744009

# %%
OUTPUT_TREES_FILE = CWD + SEP + 'newicks_step.csv'
with open(OUTPUT_TREES_FILE, "w", newline='') as fpw:
	csvwriter = csv.writer(fpw)
	csvwriter.writerow(['', 'prune_name', 'rgft_name', 'newick'])
logger.info("RUN: parse_phyml_stats_output ===========")
params_dict = (PhyML.parse_phyml_stats_file(stats_file))
#keep pinv and alpha 
freq, rates, pinv, alpha = [params_dict["fA"], params_dict["fC"], params_dict["fG"], params_dict["fT"]], [params_dict["subAC"], params_dict["subAG"], params_dict["subAT"], params_dict["subCG"],params_dict["subCT"], params_dict["subGT"]], params_dict["pInv"], params_dict["gamma"]
df = pd.DataFrame()
df["orig_ds_ll"] = float(params_dict["logL"])
root_children = orig_tree_obj.get_tree_root().get_children()
outpath_prune = CWD + SEP +'ds_summary_spr_prune.csv'
outpath_rgft = CWD + SEP +'ds_summary_spr_rgft.csv'
# Out:
# 2023-09-15 18:08:11,028 - PIP Likelyhood main script - INFO - RUN: parse_phyml_stats_output ===========

# %%
for i, prune_node in enumerate(orig_tree_obj.iter_descendants("levelorder")):
	if prune_node in root_children:
		print("SKIP TREE prune_node: ", prune_node.get_ascii(attributes=["name", "dist"]))
		continue
	prune_name = prune_node.name
	x = prune_node.get_ascii(attributes=["name", "dist"])
	#print(f"+++++++++ Iteration {i} with pruned tree: {x} \n At node name: {prune_name} \n+++++++++")
	nname, subtree1, subtree2 = tree_functions.prune_branch(orig_tree_obj, prune_name) # subtree1 is the pruned subtree. subtree2 is the remaining subtree
	#print(">> pruned node: ", nname)
	#print(">> pruned subtree1", subtree1.get_ascii(attributes=["name", "dist"]))
	#print(f">> ROOT: {subtree1.get_tree_root().name}")
	#print(">> remaining subtree2", subtree2.get_ascii(attributes=["name", "dist"]))
	#print(f">> ROOT: {subtree2.get_tree_root().name}")
	#print("================")
	with open(OUTPUT_TREES_FILE, "a", newline='') as fpa:
		csvwriter = csv.writer(fpa)
		csvwriter.writerow([str(i)+",0", prune_name, SUBTREE1, subtree1.write(format=1)])
		csvwriter.writerow([str(i)+",1", prune_name, SUBTREE2, subtree2.write(format=1)])

	for j, rgft_node in enumerate(subtree2.iter_descendants("levelorder")): # traversing over subtree2 capture cases (1) and (3)
		# skip the ROOT node when regraft 
		ind = str(i) + "," + str(j)
		rgft_name = rgft_node.name
		y = rgft_node.get_ascii(attributes=["name", "dist"])
		print(f"++++++++++++++++++ Iteration {ind} with remaining tree: {y} \n At node name: {rgft_name} \n++++++++++++++++++")
		if nname == rgft_name: # captures case (2)
			continue
		rearr_tree, preserve = tree_functions.regraft_branch(subtree2, rgft_node, subtree1, rgft_name, nname)
		
		#print(">> rearr_tree: ", rearr_tree.get_ascii(attributes=["name", "dist"]))
		#print("-- rearr_tree has ROOT: ", rearr_tree.get_tree_root().name)
		neighbor_tree_str = rearr_tree.write(format=1, format_root_node=True)

		### save tree to file by using "append"
		with open(OUTPUT_TREES_FILE, "a", newline='') as fpa:
			csvwriter = csv.writer(fpa)
			csvwriter.writerow([ind, prune_name, rgft_name, neighbor_tree_str])
		#print("====== neighbor_tree_str ==========")
		#print(neighbor_tree_str)
		#neighbor_tree_str = neighbor_tree_str.replace(";", "R:0.0;")
		total_bl = tree_functions.get_total_branch_lengths(neighbor_tree_str)
		print(f">> Total branch lenght: {total_bl}")
		ll_rearr = 0
		print(f">> PIP Likelihood: {ll_rearr}" )
		rtime = 0 

		df.loc[ind, "prune_name"], df.loc[ind, "rgft_name"] = prune_name, rgft_name
		df.loc[ind, "time"] = rtime
		df.loc[ind, "ll"] = ll_rearr

df.to_csv(outpath_prune.format("prune"))
df.to_csv(outpath_rgft.format("rgft"))
# Out:
# SKIP TREE prune_node:
#        /-Sp003, 0.17093226
# -N1, 0.0
#       |              /-Sp000, 0.88588667
#        \N4, 0.12633891
#                     |              /-Sp001, 0.21256585
#                      \N6, 0.18046101
#                                   |              /-Sp004, 0.48003642
#                                    \N8, 0.11471175
#                                                 |               /-Sp006, 0.01327609
#                                                  \N10, 0.59284149
#                                                                |               /-Sp007, 0.13766375
#                                                                 \N12, 0.04863679
#                                                                                \-Sp005, 0.12854009
# SKIP TREE prune_node:
# --Sp002, 0.11744009
# ++++++++++++++++++ Iteration 2,0 with remaining tree:
# --Sp002, 0.11744009
#  At node name: Sp002
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 2,1 with remaining tree:
#               /-Sp000, 0.88588667
# -N4, 0.12633891
#              |              /-Sp001, 0.21256585
#               \N6, 0.18046101
#                            |              /-Sp004, 0.48003642
#                             \N8, 0.11471175
#                                          |               /-Sp006, 0.01327609
#                                           \N10, 0.59284149
#                                                         |               /-Sp007, 0.13766375
#                                                          \N12, 0.04863679
#                                                                         \-Sp005, 0.12854009
#  At node name: N4
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 2,2 with remaining tree:
# --Sp000, 0.88588667
#  At node name: Sp000
# ++++++++++++++++++
# >> Total branch lenght: 3.2093299000000006
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 2,3 with remaining tree:
#               /-Sp001, 0.21256585
# -N6, 0.18046101
#              |              /-Sp004, 0.48003642
#               \N8, 0.11471175
#                            |               /-Sp006, 0.01327609
#                             \N10, 0.59284149
#                                           |               /-Sp007, 0.13766375
#                                            \N12, 0.04863679
#                                                           \-Sp005, 0.12854009
#  At node name: N6
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000008
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 2,4 with remaining tree:
# --Sp001, 0.21256585
#  At node name: Sp001
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 2,5 with remaining tree:
#               /-Sp004, 0.48003642
# -N8, 0.11471175
#              |               /-Sp006, 0.01327609
#               \N10, 0.59284149
#                             |               /-Sp007, 0.13766375
#                              \N12, 0.04863679
#                                             \-Sp005, 0.12854009
#  At node name: N8
# ++++++++++++++++++
# >> Total branch lenght: 3.2093307
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 2,6 with remaining tree:
# --Sp004, 0.48003642
#  At node name: Sp004
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000008
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 2,7 with remaining tree:
#                /-Sp006, 0.01327609
# -N10, 0.59284149
#               |               /-Sp007, 0.13766375
#                \N12, 0.04863679
#                               \-Sp005, 0.12854009
#  At node name: N10
# ++++++++++++++++++
# >> Total branch lenght: 3.2093319000000005
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 2,8 with remaining tree:
# --Sp006, 0.01327609
#  At node name: Sp006
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 2,9 with remaining tree:
#                /-Sp007, 0.13766375
# -N12, 0.04863679
#                \-Sp005, 0.12854009
#  At node name: N12
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 2,10 with remaining tree:
# --Sp007, 0.13766375
#  At node name: Sp007
# ++++++++++++++++++
# >> Total branch lenght: 3.2093307000000006
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 2,11 with remaining tree:
# --Sp005, 0.12854009
#  At node name: Sp005
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 3,0 with remaining tree:
# --Sp002, 0.11744009
#  At node name: Sp002
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 3,1 with remaining tree:
# --Sp003, 0.17093226
#  At node name: Sp003
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311000000004
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 4,0 with remaining tree:
#        /-Sp003, 0.17093226
# -N1, 0.0
#       |              /-Sp001, 0.21256585
#        \N6, 0.30679992
#                     |              /-Sp004, 0.48003642
#                      \N8, 0.11471175
#                                   |               /-Sp006, 0.01327609
#                                    \N10, 0.59284149
#                                                  |               /-Sp007, 0.13766375
#                                                   \N12, 0.04863679
#                                                                  \-Sp005, 0.12854009
#  At node name: N1
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 4,1 with remaining tree:
# --Sp002, 0.11744009
#  At node name: Sp002
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 4,2 with remaining tree:
# --Sp003, 0.17093226
#  At node name: Sp003
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311000000004
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 4,3 with remaining tree:
#               /-Sp001, 0.21256585
# -N6, 0.30679992
#              |              /-Sp004, 0.48003642
#               \N8, 0.11471175
#                            |               /-Sp006, 0.01327609
#                             \N10, 0.59284149
#                                           |               /-Sp007, 0.13766375
#                                            \N12, 0.04863679
#                                                           \-Sp005, 0.12854009
#  At node name: N6
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 4,4 with remaining tree:
# --Sp001, 0.21256585
#  At node name: Sp001
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 4,5 with remaining tree:
#               /-Sp004, 0.48003642
# -N8, 0.11471175
#              |               /-Sp006, 0.01327609
#               \N10, 0.59284149
#                             |               /-Sp007, 0.13766375
#                              \N12, 0.04863679
#                                             \-Sp005, 0.12854009
#  At node name: N8
# ++++++++++++++++++
# >> Total branch lenght: 3.2093307
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 4,6 with remaining tree:
# --Sp004, 0.48003642
#  At node name: Sp004
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 4,7 with remaining tree:
#                /-Sp006, 0.01327609
# -N10, 0.59284149
#               |               /-Sp007, 0.13766375
#                \N12, 0.04863679
#                               \-Sp005, 0.12854009
#  At node name: N10
# ++++++++++++++++++
# >> Total branch lenght: 3.2093319000000005
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 4,8 with remaining tree:
# --Sp006, 0.01327609
#  At node name: Sp006
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 4,9 with remaining tree:
#                /-Sp007, 0.13766375
# -N12, 0.04863679
#                \-Sp005, 0.12854009
#  At node name: N12
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 4,10 with remaining tree:
# --Sp007, 0.13766375
#  At node name: Sp007
# ++++++++++++++++++
# >> Total branch lenght: 3.2093307000000006
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 4,11 with remaining tree:
# --Sp005, 0.12854009
#  At node name: Sp005
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 5,0 with remaining tree:
#        /-Sp003, 0.17093226
# -N1, 0.0
#        \-Sp000, 1.01222558
#  At node name: N1
# ++++++++++++++++++
# >> Total branch lenght: 3.2093349000000004
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 5,1 with remaining tree:
# --Sp002, 0.11744009
#  At node name: Sp002
# ++++++++++++++++++
# >> Total branch lenght: 3.2093349000000004
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 5,2 with remaining tree:
# --Sp003, 0.17093226
#  At node name: Sp003
# ++++++++++++++++++
# >> Total branch lenght: 3.2093351000000006
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 5,3 with remaining tree:
# --Sp000, 1.01222558
#  At node name: Sp000
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 6,0 with remaining tree:
#        /-Sp003, 0.17093226
# -N1, 0.0
#       |              /-Sp000, 0.88588667
#        \N4, 0.12633891
#                     |                       /-Sp004, 0.48003642
#                      \N8, 0.29517276000000003
#                                            |               /-Sp006, 0.01327609
#                                             \N10, 0.59284149
#                                                           |               /-Sp007, 0.13766375
#                                                            \N12, 0.04863679
#                                                                           \-Sp005, 0.12854009
#  At node name: N1
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 6,1 with remaining tree:
# --Sp002, 0.11744009
#  At node name: Sp002
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 6,2 with remaining tree:
# --Sp003, 0.17093226
#  At node name: Sp003
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311000000004
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 6,3 with remaining tree:
#               /-Sp000, 0.88588667
# -N4, 0.12633891
#              |                       /-Sp004, 0.48003642
#               \N8, 0.29517276000000003
#                                     |               /-Sp006, 0.01327609
#                                      \N10, 0.59284149
#                                                    |               /-Sp007, 0.13766375
#                                                     \N12, 0.04863679
#                                                                    \-Sp005, 0.12854009
#  At node name: N4
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 6,4 with remaining tree:
# --Sp000, 0.88588667
#  At node name: Sp000
# ++++++++++++++++++
# >> Total branch lenght: 3.2093299
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 6,5 with remaining tree:
#                        /-Sp004, 0.48003642
# -N8, 0.29517276000000003
#                       |               /-Sp006, 0.01327609
#                        \N10, 0.59284149
#                                      |               /-Sp007, 0.13766375
#                                       \N12, 0.04863679
#                                                      \-Sp005, 0.12854009
#  At node name: N8
# ++++++++++++++++++
# >> Total branch lenght: 3.2093299
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 6,6 with remaining tree:
# --Sp004, 0.48003642
#  At node name: Sp004
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 6,7 with remaining tree:
#                /-Sp006, 0.01327609
# -N10, 0.59284149
#               |               /-Sp007, 0.13766375
#                \N12, 0.04863679
#                               \-Sp005, 0.12854009
#  At node name: N10
# ++++++++++++++++++
# >> Total branch lenght: 3.2093319000000005
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 6,8 with remaining tree:
# --Sp006, 0.01327609
#  At node name: Sp006
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 6,9 with remaining tree:
#                /-Sp007, 0.13766375
# -N12, 0.04863679
#                \-Sp005, 0.12854009
#  At node name: N12
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 6,10 with remaining tree:
# --Sp007, 0.13766375
#  At node name: Sp007
# ++++++++++++++++++
# >> Total branch lenght: 3.2093307000000006
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 6,11 with remaining tree:
# --Sp005, 0.12854009
#  At node name: Sp005
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 7,0 with remaining tree:
#        /-Sp003, 0.17093226
# -N1, 0.0
#       |              /-Sp000, 0.88588667
#        \N4, 0.12633891
#                      \-Sp001, 0.39302686
#  At node name: N1
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 7,1 with remaining tree:
# --Sp002, 0.11744009
#  At node name: Sp002
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 7,2 with remaining tree:
# --Sp003, 0.17093226
#  At node name: Sp003
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311000000004
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 7,3 with remaining tree:
#               /-Sp000, 0.88588667
# -N4, 0.12633891
#               \-Sp001, 0.39302686
#  At node name: N4
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 7,4 with remaining tree:
# --Sp000, 0.88588667
#  At node name: Sp000
# ++++++++++++++++++
# >> Total branch lenght: 3.2093299000000006
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 7,5 with remaining tree:
# --Sp001, 0.39302686
#  At node name: Sp001
# ++++++++++++++++++
# >> Total branch lenght: 3.2093299
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 8,0 with remaining tree:
#        /-Sp003, 0.17093226
# -N1, 0.0
#       |              /-Sp000, 0.88588667
#        \N4, 0.12633891
#                     |              /-Sp001, 0.21256585
#                      \N6, 0.18046101
#                                   |               /-Sp006, 0.01327609
#                                    \N10, 0.70755324
#                                                  |               /-Sp007, 0.13766375
#                                                   \N12, 0.04863679
#                                                                  \-Sp005, 0.12854009
#  At node name: N1
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 8,1 with remaining tree:
# --Sp002, 0.11744009
#  At node name: Sp002
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 8,2 with remaining tree:
# --Sp003, 0.17093226
#  At node name: Sp003
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 8,3 with remaining tree:
#               /-Sp000, 0.88588667
# -N4, 0.12633891
#              |              /-Sp001, 0.21256585
#               \N6, 0.18046101
#                            |               /-Sp006, 0.01327609
#                             \N10, 0.70755324
#                                           |               /-Sp007, 0.13766375
#                                            \N12, 0.04863679
#                                                           \-Sp005, 0.12854009
#  At node name: N4
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 8,4 with remaining tree:
# --Sp000, 0.88588667
#  At node name: Sp000
# ++++++++++++++++++
# >> Total branch lenght: 3.2093299000000006
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 8,5 with remaining tree:
#               /-Sp001, 0.21256585
# -N6, 0.18046101
#              |               /-Sp006, 0.01327609
#               \N10, 0.70755324
#                             |               /-Sp007, 0.13766375
#                              \N12, 0.04863679
#                                             \-Sp005, 0.12854009
#  At node name: N6
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 8,6 with remaining tree:
# --Sp001, 0.21256585
#  At node name: Sp001
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 8,7 with remaining tree:
#                /-Sp006, 0.01327609
# -N10, 0.70755324
#               |               /-Sp007, 0.13766375
#                \N12, 0.04863679
#                               \-Sp005, 0.12854009
#  At node name: N10
# ++++++++++++++++++
# >> Total branch lenght: 3.2093319000000005
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 8,8 with remaining tree:
# --Sp006, 0.01327609
#  At node name: Sp006
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 8,9 with remaining tree:
#                /-Sp007, 0.13766375
# -N12, 0.04863679
#                \-Sp005, 0.12854009
#  At node name: N12
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 8,10 with remaining tree:
# --Sp007, 0.13766375
#  At node name: Sp007
# ++++++++++++++++++
# >> Total branch lenght: 3.2093307000000006
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 8,11 with remaining tree:
# --Sp005, 0.12854009
#  At node name: Sp005
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 9,0 with remaining tree:
#        /-Sp003, 0.17093226
# -N1, 0.0
#       |              /-Sp000, 0.88588667
#        \N4, 0.12633891
#                     |              /-Sp001, 0.21256585
#                      \N6, 0.18046101
#                                    \-Sp004, 0.59474817
#  At node name: N1
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 9,1 with remaining tree:
# --Sp002, 0.11744009
#  At node name: Sp002
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 9,2 with remaining tree:
# --Sp003, 0.17093226
#  At node name: Sp003
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 9,3 with remaining tree:
#               /-Sp000, 0.88588667
# -N4, 0.12633891
#              |              /-Sp001, 0.21256585
#               \N6, 0.18046101
#                             \-Sp004, 0.59474817
#  At node name: N4
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 9,4 with remaining tree:
# --Sp000, 0.88588667
#  At node name: Sp000
# ++++++++++++++++++
# >> Total branch lenght: 3.2093299000000006
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 9,5 with remaining tree:
#               /-Sp001, 0.21256585
# -N6, 0.18046101
#               \-Sp004, 0.59474817
#  At node name: N6
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 9,6 with remaining tree:
# --Sp001, 0.21256585
#  At node name: Sp001
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 9,7 with remaining tree:
# --Sp004, 0.59474817
#  At node name: Sp004
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000003
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 10,0 with remaining tree:
#        /-Sp003, 0.17093226
# -N1, 0.0
#       |              /-Sp000, 0.88588667
#        \N4, 0.12633891
#                     |              /-Sp001, 0.21256585
#                      \N6, 0.18046101
#                                   |              /-Sp004, 0.48003642
#                                    \N8, 0.11471175
#                                                 |               /-Sp007, 0.13766375
#                                                  \N12, 0.64147828
#                                                                 \-Sp005, 0.12854009
#  At node name: N1
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 10,1 with remaining tree:
# --Sp002, 0.11744009
#  At node name: Sp002
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 10,2 with remaining tree:
# --Sp003, 0.17093226
#  At node name: Sp003
# ++++++++++++++++++
# >> Total branch lenght: 3.2093312999999997
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 10,3 with remaining tree:
#               /-Sp000, 0.88588667
# -N4, 0.12633891
#              |              /-Sp001, 0.21256585
#               \N6, 0.18046101
#                            |              /-Sp004, 0.48003642
#                             \N8, 0.11471175
#                                          |               /-Sp007, 0.13766375
#                                           \N12, 0.64147828
#                                                          \-Sp005, 0.12854009
#  At node name: N4
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 10,4 with remaining tree:
# --Sp000, 0.88588667
#  At node name: Sp000
# ++++++++++++++++++
# >> Total branch lenght: 3.2093301
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 10,5 with remaining tree:
#               /-Sp001, 0.21256585
# -N6, 0.18046101
#              |              /-Sp004, 0.48003642
#               \N8, 0.11471175
#                            |               /-Sp007, 0.13766375
#                             \N12, 0.64147828
#                                            \-Sp005, 0.12854009
#  At node name: N6
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 10,6 with remaining tree:
# --Sp001, 0.21256585
#  At node name: Sp001
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 10,7 with remaining tree:
#               /-Sp004, 0.48003642
# -N8, 0.11471175
#              |               /-Sp007, 0.13766375
#               \N12, 0.64147828
#                              \-Sp005, 0.12854009
#  At node name: N8
# ++++++++++++++++++
# >> Total branch lenght: 3.2093308999999994
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 10,8 with remaining tree:
# --Sp004, 0.48003642
#  At node name: Sp004
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311000000004
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 10,9 with remaining tree:
#                /-Sp007, 0.13766375
# -N12, 0.64147828
#                \-Sp005, 0.12854009
#  At node name: N12
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311000000004
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 10,10 with remaining tree:
# --Sp007, 0.13766375
#  At node name: Sp007
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309000000008
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 10,11 with remaining tree:
# --Sp005, 0.12854009
#  At node name: Sp005
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311000000004
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 11,0 with remaining tree:
#        /-Sp003, 0.17093226
# -N1, 0.0
#       |              /-Sp000, 0.88588667
#        \N4, 0.12633891
#                     |              /-Sp001, 0.21256585
#                      \N6, 0.18046101
#                                   |              /-Sp004, 0.48003642
#                                    \N8, 0.11471175
#                                                  \-Sp006, 0.6061175799999999
#  At node name: N1
# ++++++++++++++++++
# >> Total branch lenght: 3.2093317999999997
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 11,1 with remaining tree:
# --Sp002, 0.11744009
#  At node name: Sp002
# ++++++++++++++++++
# >> Total branch lenght: 3.2093317999999997
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 11,2 with remaining tree:
# --Sp003, 0.17093226
#  At node name: Sp003
# ++++++++++++++++++
# >> Total branch lenght: 3.209332
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 11,3 with remaining tree:
#               /-Sp000, 0.88588667
# -N4, 0.12633891
#              |              /-Sp001, 0.21256585
#               \N6, 0.18046101
#                            |              /-Sp004, 0.48003642
#                             \N8, 0.11471175
#                                           \-Sp006, 0.6061175799999999
#  At node name: N4
# ++++++++++++++++++
# >> Total branch lenght: 3.2093317999999997
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 11,4 with remaining tree:
# --Sp000, 0.88588667
#  At node name: Sp000
# ++++++++++++++++++
# >> Total branch lenght: 3.2093308
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 11,5 with remaining tree:
#               /-Sp001, 0.21256585
# -N6, 0.18046101
#              |              /-Sp004, 0.48003642
#               \N8, 0.11471175
#                             \-Sp006, 0.6061175799999999
#  At node name: N6
# ++++++++++++++++++
# >> Total branch lenght: 3.2093317999999997
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 11,6 with remaining tree:
# --Sp001, 0.21256585
#  At node name: Sp001
# ++++++++++++++++++
# >> Total branch lenght: 3.2093317999999997
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 11,7 with remaining tree:
#               /-Sp004, 0.48003642
# -N8, 0.11471175
#               \-Sp006, 0.6061175799999999
#  At node name: N8
# ++++++++++++++++++
# >> Total branch lenght: 3.2093315999999996
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 11,8 with remaining tree:
# --Sp004, 0.48003642
#  At node name: Sp004
# ++++++++++++++++++
# >> Total branch lenght: 3.2093318
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 11,9 with remaining tree:
# --Sp006, 0.6061175799999999
#  At node name: Sp006
# ++++++++++++++++++
# >> Total branch lenght: 3.2093318000000006
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 12,0 with remaining tree:
#        /-Sp003, 0.17093226
# -N1, 0.0
#       |              /-Sp000, 0.88588667
#        \N4, 0.12633891
#                     |              /-Sp001, 0.21256585
#                      \N6, 0.18046101
#                                   |              /-Sp004, 0.48003642
#                                    \N8, 0.11471175
#                                                 |               /-Sp006, 0.01327609
#                                                  \N10, 0.59284149
#                                                                 \-Sp005, 0.17717687999999998
#  At node name: N1
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 12,1 with remaining tree:
# --Sp002, 0.11744009
#  At node name: Sp002
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 12,2 with remaining tree:
# --Sp003, 0.17093226
#  At node name: Sp003
# ++++++++++++++++++
# >> Total branch lenght: 3.2093313
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 12,3 with remaining tree:
#               /-Sp000, 0.88588667
# -N4, 0.12633891
#              |              /-Sp001, 0.21256585
#               \N6, 0.18046101
#                            |              /-Sp004, 0.48003642
#                             \N8, 0.11471175
#                                          |               /-Sp006, 0.01327609
#                                           \N10, 0.59284149
#                                                          \-Sp005, 0.17717687999999998
#  At node name: N4
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 12,4 with remaining tree:
# --Sp000, 0.88588667
#  At node name: Sp000
# ++++++++++++++++++
# >> Total branch lenght: 3.2093301
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 12,5 with remaining tree:
#               /-Sp001, 0.21256585
# -N6, 0.18046101
#              |              /-Sp004, 0.48003642
#               \N8, 0.11471175
#                            |               /-Sp006, 0.01327609
#                             \N10, 0.59284149
#                                            \-Sp005, 0.17717687999999998
#  At node name: N6
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 12,6 with remaining tree:
# --Sp001, 0.21256585
#  At node name: Sp001
# ++++++++++++++++++
# >> Total branch lenght: 3.2093310999999995
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 12,7 with remaining tree:
#               /-Sp004, 0.48003642
# -N8, 0.11471175
#              |               /-Sp006, 0.01327609
#               \N10, 0.59284149
#                              \-Sp005, 0.17717687999999998
#  At node name: N8
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 12,8 with remaining tree:
# --Sp004, 0.48003642
#  At node name: Sp004
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 12,9 with remaining tree:
#                /-Sp006, 0.01327609
# -N10, 0.59284149
#                \-Sp005, 0.17717687999999998
#  At node name: N10
# ++++++++++++++++++
# >> Total branch lenght: 3.2093321
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 12,10 with remaining tree:
# --Sp006, 0.01327609
#  At node name: Sp006
# ++++++++++++++++++
# >> Total branch lenght: 3.2093310999999995
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 12,11 with remaining tree:
# --Sp005, 0.17717687999999998
#  At node name: Sp005
# ++++++++++++++++++
# >> Total branch lenght: 3.2093309
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 13,0 with remaining tree:
#        /-Sp003, 0.17093226
# -N1, 0.0
#       |              /-Sp000, 0.88588667
#        \N4, 0.12633891
#                     |              /-Sp001, 0.21256585
#                      \N6, 0.18046101
#                                   |              /-Sp004, 0.48003642
#                                    \N8, 0.11471175
#                                                 |               /-Sp006, 0.01327609
#                                                  \N10, 0.59284149
#                                                                 \-Sp007, 0.18630054000000001
#  At node name: N1
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 13,1 with remaining tree:
# --Sp002, 0.11744009
#  At node name: Sp002
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 13,2 with remaining tree:
# --Sp003, 0.17093226
#  At node name: Sp003
# ++++++++++++++++++
# >> Total branch lenght: 3.2093312999999997
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 13,3 with remaining tree:
#               /-Sp000, 0.88588667
# -N4, 0.12633891
#              |              /-Sp001, 0.21256585
#               \N6, 0.18046101
#                            |              /-Sp004, 0.48003642
#                             \N8, 0.11471175
#                                          |               /-Sp006, 0.01327609
#                                           \N10, 0.59284149
#                                                          \-Sp007, 0.18630054000000001
#  At node name: N4
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 13,4 with remaining tree:
# --Sp000, 0.88588667
#  At node name: Sp000
# ++++++++++++++++++
# >> Total branch lenght: 3.2093301
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 13,5 with remaining tree:
#               /-Sp001, 0.21256585
# -N6, 0.18046101
#              |              /-Sp004, 0.48003642
#               \N8, 0.11471175
#                            |               /-Sp006, 0.01327609
#                             \N10, 0.59284149
#                                            \-Sp007, 0.18630054000000001
#  At node name: N6
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 13,6 with remaining tree:
# --Sp001, 0.21256585
#  At node name: Sp001
# ++++++++++++++++++
# >> Total branch lenght: 3.2093310999999995
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 13,7 with remaining tree:
#               /-Sp004, 0.48003642
# -N8, 0.11471175
#              |               /-Sp006, 0.01327609
#               \N10, 0.59284149
#                              \-Sp007, 0.18630054000000001
#  At node name: N8
# ++++++++++++++++++
# >> Total branch lenght: 3.2093308999999994
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 13,8 with remaining tree:
# --Sp004, 0.48003642
#  At node name: Sp004
# ++++++++++++++++++
# >> Total branch lenght: 3.2093311
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 13,9 with remaining tree:
#                /-Sp006, 0.01327609
# -N10, 0.59284149
#                \-Sp007, 0.18630054000000001
#  At node name: N10
# ++++++++++++++++++
# >> Total branch lenght: 3.2093321
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 13,10 with remaining tree:
# --Sp006, 0.01327609
#  At node name: Sp006
# ++++++++++++++++++
# >> Total branch lenght: 3.2093310999999995
# >> PIP Likelihood: 0
# ++++++++++++++++++ Iteration 13,11 with remaining tree:
# --Sp007, 0.18630054000000001
#  At node name: Sp007
# ++++++++++++++++++
# >> Total branch lenght: 3.2093307
# >> PIP Likelihood: 0
