# %%
from Bio.Align import AlignInfo
from Bio import AlignIO


from Tools import PhyML, RaxML
from Utils import tree_functions
from Utils.defs_PhyAI import ROOTLIKE_NAME, TEST_DATA_PATH, SEP, DEFAULT_MODEL, SUBTREE1, SUBTREE2, LEARNING_DATA

# %%
def validate_input(msa_file, user_tree_file):
	"""
	:param msa_file: the path to an MSA file, one of biopython's formats
	:param user_tree_file: (optional) the path to a user tree file, if fixed tree was desired
	:return: a biopython object of the msa and an ete3 object of the tree if exists
	"""
	# identify format and retrieve all MSAs
	for aln_format in ["clustal", "emboss", "fasta", "fasta-m10", "ig", "maf", "mauve", "nexus", "phylip-relaxed", "phylip-sequential", "stockholm"]:
		try:
			msa_obj = AlignIO.read(msa_file, format=aln_format)
			print("INFO - The MSA file is format: " + aln_format)
			break
		except Exception:
			msa_obj = None
	if msa_obj is None:
		print("ERROR - Error occured: the input file is not a valid alignmnet in a supported format.\n"
					 "Please verify that all sequences are at the same length and that the input format is correct.")
	# validate MSA characters
	msa_info = AlignInfo.SummaryInfo(msa_obj)
	aln_letters = msa_info._get_all_letters()
	for let in aln_letters:
		if not (let.lower() in "acgt-"):
			print("WARNING - There are characters that are not nucleotides or gaps in your input MSA.")
			break
	# validate tree file in Newick format and suits the msa
	tree_obj = None
	if user_tree_file:
		try:
			with open(user_tree_file) as fpr:
				tree_obj = tree_functions.get_newick_tree(fpr.read().strip())
		except:
			print("ERROR - Tree file is invalid. Please verify that it's in Newick format.")
		print(tree_obj)
		# assert that the tree matches the corresponding MSA
		leaves = sorted([node.name for node in tree_obj.get_leaves()])
		seq_names = sorted([rec.id for rec in msa_obj])
		if len(leaves) != len(seq_names) or (not all(x == y for x,y  in zip(seq_names,leaves))):
			print("ERROR - The tips of the tree and the MSA sequences names do not match")

	return msa_obj

# %%
#for folder_name in os.listdir(TEST_DATA_PATH):
folder_name = '8'
CWD = TEST_DATA_PATH + folder_name + SEP
orig_msa_file = CWD + 'real_msa.phy'
run_id = DEFAULT_MODEL + "_" + folder_name
stats_file, tree_file = PhyML.run_phyml(orig_msa_file, DEFAULT_MODEL, run_id=run_id)
#msa_obj = validate_input(orig_msa_file, tree_file)

orig_tree_obj = tree_functions.get_phylo_tree(tree_file, orig_msa_file)
orig_tree_obj.get_tree_root().name = ROOTLIKE_NAME
print(orig_tree_obj.get_ascii(attributes=["name", "dist"]))
# Out:
# INFO - Running PhyML: base_model='GTR' pinv=True gamma=True run_id='GTR+I+G_8'
# INFO - Running PhyML: execution_tags='-m 012345 -f m -v e -a e -c 4 -o tlr -d nt -n 1 -b 0 --no_memory_check --run_id GTR+I+G_8'
# INFO - The MSA file is format: phylip-relaxed
#
#       /-Sp000
#    /-|
#   |  |   /-Sp003
#   |   \-|
#   |     |   /-Sp004
#   |      \-|
#   |        |   /-Sp001
# --|         \-|
#   |           |   /-Sp006
#   |            \-|
#   |              |   /-Sp005
#   |               \-|
#   |                  \-Sp007
#   |
#    \-Sp002
#
#                      /-Sp000, 4.10264
#               /N1, 0.0
#              |      |             /-Sp003, 0.176516
#              |       \N4, 0.0238354
#              |                   |            /-Sp004, 1.58237
#              |                    \N6, 0.769354
#              |                               |            /-Sp001, 0.146422
# -ROOT_LIKE, 0.0                               \N8, 0.117189
#              |                                           |            /-Sp006, 1.136e-05
#              |                                            \N10, 2.22572
#              |                                                       |              /-Sp005, 0.158931
#              |                                                        \N12, 0.0757508
#              |                                                                      \-Sp007, 0.181737
#              |
#               \-Sp002, 0.132302

# %%
import pandas as pd
import csv

OUTPUT_TREES_FILE = CWD +  'newicks_step.csv'
with open(OUTPUT_TREES_FILE, "w", newline='') as fpw:
	csvwriter = csv.writer(fpw)
	csvwriter.writerow(['', 'prune_name', 'rgft_name', 'newick'])
print("RUN: parse_phyml_stats_output ===========")
params_dict = (PhyML.parse_phyml_stats_file(stats_file))
#keep pinv and alpha 
freq, rates, pinv, alpha = [params_dict["fA"], params_dict["fC"], params_dict["fG"], params_dict["fT"]], [params_dict["subAC"], params_dict["subAG"], params_dict["subAT"], params_dict["subCG"],params_dict["subCT"], params_dict["subGT"]], params_dict["pInv"], params_dict["gamma"]
df = pd.DataFrame()
df["orig_ds_ll"] = float(params_dict["logL"])
root_children = orig_tree_obj.get_tree_root().get_children()
outpath_prune = CWD + 'ds_summary_SPR_prune.csv'
outpath_rgft = CWD + 'ds_summary_SPR_rgft.csv'
# Out:
# RUN: parse_phyml_stats_output ===========

# %%
for i, prune_node in enumerate(orig_tree_obj.iter_descendants("levelorder")):
	if prune_node in root_children:
		print("SKIP TREE prune_node: ", prune_node.get_ascii(attributes=["name", "dist"]))
		continue
	prune_name = prune_node.name
	x = prune_node.get_ascii(attributes=["name", "dist"])
	#print(f"+++++++++ Iteration {i} with pruned tree: {x} \n At node name: {prune_name} \n+++++++++")
	nname, subtree1, subtree2 = tree_functions.prune_branch(orig_tree_obj, prune_name) # subtree1 is the pruned subtree. subtree2 is the remaining subtree
	#print(">> pruned node: ", nname)
	#print(">> pruned subtree1", subtree1.get_ascii(attributes=["name", "dist"]))
	#print(f">> ROOT: {subtree1.get_tree_root().name}")
	#print(">> remaining subtree2", subtree2.get_ascii(attributes=["name", "dist"]))
	#print(f">> ROOT: {subtree2.get_tree_root().name}")
	#print("================")
	with open(OUTPUT_TREES_FILE, "a", newline='') as fpa:
		csvwriter = csv.writer(fpa)
		csvwriter.writerow([str(i)+",0", prune_name, SUBTREE1, subtree1.write(format=1)])
		csvwriter.writerow([str(i)+",1", prune_name, SUBTREE2, subtree2.write(format=1)])

	for j, rgft_node in enumerate(subtree2.iter_descendants("levelorder")): # traversing over subtree2 capture cases (1) and (3)
		# skip the ROOT node when regraft 
		ind = str(i) + "," + str(j)
		rgft_name = rgft_node.name
		y = rgft_node.get_ascii(attributes=["name", "dist"])
		print(f"++++++++++++++++++ Iteration {ind} with remaining tree: {y} \n At node name: {rgft_name} \n++++++++++++++++++")
		if nname == rgft_name: # captures case (2)
			continue
		rearr_tree, preserve = tree_functions.regraft_branch(subtree2, rgft_node, subtree1, rgft_name, nname)
		
		#print(">> rearr_tree: ", rearr_tree.get_ascii(attributes=["name", "dist"]))
		#print("-- rearr_tree has ROOT: ", rearr_tree.get_tree_root().name)
		neighbor_tree_str = rearr_tree.write(format=1, format_root_node=True)

		### save tree to file by using "append"
		with open(OUTPUT_TREES_FILE, "a", newline='') as fpa:
			csvwriter = csv.writer(fpa)
			csvwriter.writerow([ind, prune_name, rgft_name, neighbor_tree_str])
		#print("====== neighbor_tree_str ==========")
		#print(neighbor_tree_str)
		#neighbor_tree_str = neighbor_tree_str.replace(";", "R:0.0;")
		total_bl = tree_functions.get_total_branch_lengths(neighbor_tree_str)
		ll_rearr, rtime = RaxML.call_raxml_mem(neighbor_tree_str, orig_msa_file, rates, pinv, alpha, freq)
		print(f">> Total branch lenght: {total_bl}")
		print(f">> PIP Likelihood: {ll_rearr}" )

		df.loc[ind, "prune_name"], df.loc[ind, "rgft_name"] = prune_name, rgft_name
		df.loc[ind, "prune_name"], df.loc[ind, "rgft_name"] = prune_name, rgft_name
		df.loc[ind, "time"] = rtime
		df.loc[ind, "ll"] = ll_rearr

df.to_csv(outpath_prune.format("prune"))
df.to_csv(outpath_rgft.format("rgft"))
# Out:
# SKIP TREE prune_node:
#        /-Sp000, 4.10264
# -N1, 0.0
#       |             /-Sp003, 0.176516
#        \N4, 0.0238354
#                    |            /-Sp004, 1.58237
#                     \N6, 0.769354
#                                |            /-Sp001, 0.146422
#                                 \N8, 0.117189
#                                            |            /-Sp006, 1.136e-05
#                                             \N10, 2.22572
#                                                        |              /-Sp005, 0.158931
#                                                         \N12, 0.0757508
#                                                                       \-Sp007, 0.181737
# SKIP TREE prune_node:
# --Sp002, 0.132302
# ++++++++++++++++++ Iteration 2,0 with remaining tree:
# --Sp002, 0.132302
#  At node name: Sp002
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4578.072444'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4578.072444
# ++++++++++++++++++ Iteration 2,1 with remaining tree:
#              /-Sp003, 0.176516
# -N4, 0.0238354
#             |            /-Sp004, 1.58237
#              \N6, 0.769354
#                         |            /-Sp001, 0.146422
#                          \N8, 0.117189
#                                     |            /-Sp006, 1.136e-05
#                                      \N10, 2.22572
#                                                 |              /-Sp005, 0.158931
#                                                  \N12, 0.0757508
#                                                                \-Sp007, 0.181737
#  At node name: N4
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4578.049401'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4578.049401
# ++++++++++++++++++ Iteration 2,2 with remaining tree:
# --Sp003, 0.176516
#  At node name: Sp003
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4578.673124'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4578.673124
# ++++++++++++++++++ Iteration 2,3 with remaining tree:
#             /-Sp004, 1.58237
# -N6, 0.769354
#            |            /-Sp001, 0.146422
#             \N8, 0.117189
#                        |            /-Sp006, 1.136e-05
#                         \N10, 2.22572
#                                    |              /-Sp005, 0.158931
#                                     \N12, 0.0757508
#                                                   \-Sp007, 0.181737
#  At node name: N6
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4578.858457'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4578.858457
# ++++++++++++++++++ Iteration 2,4 with remaining tree:
# --Sp004, 1.58237
#  At node name: Sp004
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2809, 2842), match='Final LogLikelihood: -4584.239469'>
# >> Total branch lenght: 9.692778560000002
# >> PIP Likelihood: -4584.239469
# ++++++++++++++++++ Iteration 2,5 with remaining tree:
#             /-Sp001, 0.146422
# -N8, 0.117189
#            |            /-Sp006, 1.136e-05
#             \N10, 2.22572
#                        |              /-Sp005, 0.158931
#                         \N12, 0.0757508
#                                       \-Sp007, 0.181737
#  At node name: N8
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2809, 2842), match='Final LogLikelihood: -4584.573740'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4584.573740
# ++++++++++++++++++ Iteration 2,6 with remaining tree:
# --Sp001, 0.146422
#  At node name: Sp001
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4585.449471'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4585.449471
# ++++++++++++++++++ Iteration 2,7 with remaining tree:
#             /-Sp006, 1.136e-05
# -N10, 2.22572
#            |              /-Sp005, 0.158931
#             \N12, 0.0757508
#                           \-Sp007, 0.181737
#  At node name: N10
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4585.127922'>
# >> Total branch lenght: 9.692778559999999
# >> PIP Likelihood: -4585.127922
# ++++++++++++++++++ Iteration 2,8 with remaining tree:
# --Sp006, 1.136e-05
#  At node name: Sp006
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4594.318619'>
# >> Total branch lenght: 9.692778559999999
# >> PIP Likelihood: -4594.318619
# ++++++++++++++++++ Iteration 2,9 with remaining tree:
#               /-Sp005, 0.158931
# -N12, 0.0757508
#               \-Sp007, 0.181737
#  At node name: N12
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4594.519530'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4594.519530
# ++++++++++++++++++ Iteration 2,10 with remaining tree:
# --Sp005, 0.158931
#  At node name: Sp005
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4595.380347'>
# >> Total branch lenght: 9.692778559999999
# >> PIP Likelihood: -4595.380347
# ++++++++++++++++++ Iteration 2,11 with remaining tree:
# --Sp007, 0.181737
#  At node name: Sp007
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2815, 2848), match='Final LogLikelihood: -4595.650209'>
# >> Total branch lenght: 9.692778559999999
# >> PIP Likelihood: -4595.650209
# ++++++++++++++++++ Iteration 3,0 with remaining tree:
# --Sp002, 0.132302
#  At node name: Sp002
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4578.118172'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4578.118172
# ++++++++++++++++++ Iteration 3,1 with remaining tree:
# --Sp000, 4.10264
#  At node name: Sp000
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4578.019646'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4578.019646
# ++++++++++++++++++ Iteration 4,0 with remaining tree:
#        /-Sp000, 4.10264
# -N1, 0.0
#       |                      /-Sp004, 1.58237
#        \N6, 0.7931893999999999
#                             |            /-Sp001, 0.146422
#                              \N8, 0.117189
#                                         |            /-Sp006, 1.136e-05
#                                          \N10, 2.22572
#                                                     |              /-Sp005, 0.158931
#                                                      \N12, 0.0757508
#                                                                    \-Sp007, 0.181737
#  At node name: N1
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4578.098794'>
# >> Total branch lenght: 9.69277816
# >> PIP Likelihood: -4578.098794
# ++++++++++++++++++ Iteration 4,1 with remaining tree:
# --Sp002, 0.132302
#  At node name: Sp002
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2809, 2842), match='Final LogLikelihood: -4578.394032'>
# >> Total branch lenght: 9.69277816
# >> PIP Likelihood: -4578.394032
# ++++++++++++++++++ Iteration 4,2 with remaining tree:
# --Sp000, 4.10264
#  At node name: Sp000
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4578.819662'>
# >> Total branch lenght: 9.692778160000001
# >> PIP Likelihood: -4578.819662
# ++++++++++++++++++ Iteration 4,3 with remaining tree:
#                       /-Sp004, 1.58237
# -N6, 0.7931893999999999
#                      |            /-Sp001, 0.146422
#                       \N8, 0.117189
#                                  |            /-Sp006, 1.136e-05
#                                   \N10, 2.22572
#                                              |              /-Sp005, 0.158931
#                                               \N12, 0.0757508
#                                                             \-Sp007, 0.181737
#  At node name: N6
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2815, 2848), match='Final LogLikelihood: -4578.259368'>
# >> Total branch lenght: 9.69277916
# >> PIP Likelihood: -4578.259368
# ++++++++++++++++++ Iteration 4,4 with remaining tree:
# --Sp004, 1.58237
#  At node name: Sp004
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4603.999102'>
# >> Total branch lenght: 9.692778160000001
# >> PIP Likelihood: -4603.999102
# ++++++++++++++++++ Iteration 4,5 with remaining tree:
#             /-Sp001, 0.146422
# -N8, 0.117189
#            |            /-Sp006, 1.136e-05
#             \N10, 2.22572
#                        |              /-Sp005, 0.158931
#                         \N12, 0.0757508
#                                       \-Sp007, 0.181737
#  At node name: N8
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4603.435005'>
# >> Total branch lenght: 9.692778160000001
# >> PIP Likelihood: -4603.435005
# ++++++++++++++++++ Iteration 4,6 with remaining tree:
# --Sp001, 0.146422
#  At node name: Sp001
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2809, 2842), match='Final LogLikelihood: -4616.470291'>
# >> Total branch lenght: 9.692778160000001
# >> PIP Likelihood: -4616.470291
# ++++++++++++++++++ Iteration 4,7 with remaining tree:
#             /-Sp006, 1.136e-05
# -N10, 2.22572
#            |              /-Sp005, 0.158931
#             \N12, 0.0757508
#                           \-Sp007, 0.181737
#  At node name: N10
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4616.419083'>
# >> Total branch lenght: 9.69277816
# >> PIP Likelihood: -4616.419083
# ++++++++++++++++++ Iteration 4,8 with remaining tree:
# --Sp006, 1.136e-05
#  At node name: Sp006
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4833.737893'>
# >> Total branch lenght: 9.692778159999998
# >> PIP Likelihood: -4833.737893
# ++++++++++++++++++ Iteration 4,9 with remaining tree:
#               /-Sp005, 0.158931
# -N12, 0.0757508
#               \-Sp007, 0.181737
#  At node name: N12
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2809, 2842), match='Final LogLikelihood: -4834.142374'>
# >> Total branch lenght: 9.692778160000001
# >> PIP Likelihood: -4834.142374
# ++++++++++++++++++ Iteration 4,10 with remaining tree:
# --Sp005, 0.158931
#  At node name: Sp005
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4835.426395'>
# >> Total branch lenght: 9.692778159999998
# >> PIP Likelihood: -4835.426395
# ++++++++++++++++++ Iteration 4,11 with remaining tree:
# --Sp007, 0.181737
#  At node name: Sp007
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4835.591823'>
# >> Total branch lenght: 9.692778159999998
# >> PIP Likelihood: -4835.591823
# ++++++++++++++++++ Iteration 5,0 with remaining tree:
#        /-Sp000, 4.10264
# -N1, 0.0
#        \-Sp003, 0.2003514
#  At node name: N1
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4578.361263'>
# >> Total branch lenght: 9.692778160000003
# >> PIP Likelihood: -4578.361263
# ++++++++++++++++++ Iteration 5,1 with remaining tree:
# --Sp002, 0.132302
#  At node name: Sp002
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4578.382607'>
# >> Total branch lenght: 9.69277816
# >> PIP Likelihood: -4578.382607
# ++++++++++++++++++ Iteration 5,2 with remaining tree:
# --Sp000, 4.10264
#  At node name: Sp000
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2815, 2848), match='Final LogLikelihood: -4578.194244'>
# >> Total branch lenght: 9.69277816
# >> PIP Likelihood: -4578.194244
# ++++++++++++++++++ Iteration 5,3 with remaining tree:
# --Sp003, 0.2003514
#  At node name: Sp003
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4578.298425'>
# >> Total branch lenght: 9.69277916
# >> PIP Likelihood: -4578.298425
# ++++++++++++++++++ Iteration 6,0 with remaining tree:
#        /-Sp000, 4.10264
# -N1, 0.0
#       |             /-Sp003, 0.176516
#        \N4, 0.0238354
#                    |            /-Sp001, 0.146422
#                     \N8, 0.886543
#                                |            /-Sp006, 1.136e-05
#                                 \N10, 2.22572
#                                            |              /-Sp005, 0.158931
#                                             \N12, 0.0757508
#                                                           \-Sp007, 0.181737
#  At node name: N1
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4603.769115'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4603.769115
# ++++++++++++++++++ Iteration 6,1 with remaining tree:
# --Sp002, 0.132302
#  At node name: Sp002
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4603.484837'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4603.484837
# ++++++++++++++++++ Iteration 6,2 with remaining tree:
# --Sp000, 4.10264
#  At node name: Sp000
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2815, 2848), match='Final LogLikelihood: -4602.703353'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4602.703353
# ++++++++++++++++++ Iteration 6,3 with remaining tree:
#              /-Sp003, 0.176516
# -N4, 0.0238354
#             |            /-Sp001, 0.146422
#              \N8, 0.886543
#                         |            /-Sp006, 1.136e-05
#                          \N10, 2.22572
#                                     |              /-Sp005, 0.158931
#                                      \N12, 0.0757508
#                                                    \-Sp007, 0.181737
#  At node name: N4
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4603.100423'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4603.100423
# ++++++++++++++++++ Iteration 6,4 with remaining tree:
# --Sp003, 0.176516
#  At node name: Sp003
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4603.296561'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4603.296561
# ++++++++++++++++++ Iteration 6,5 with remaining tree:
#             /-Sp001, 0.146422
# -N8, 0.886543
#            |            /-Sp006, 1.136e-05
#             \N10, 2.22572
#                        |              /-Sp005, 0.158931
#                         \N12, 0.0757508
#                                       \-Sp007, 0.181737
#  At node name: N8
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4578.087724'>
# >> Total branch lenght: 9.692777560000003
# >> PIP Likelihood: -4578.087724
# ++++++++++++++++++ Iteration 6,6 with remaining tree:
# --Sp001, 0.146422
#  At node name: Sp001
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2809, 2842), match='Final LogLikelihood: -4578.470315'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4578.470315
# ++++++++++++++++++ Iteration 6,7 with remaining tree:
#             /-Sp006, 1.136e-05
# -N10, 2.22572
#            |              /-Sp005, 0.158931
#             \N12, 0.0757508
#                           \-Sp007, 0.181737
#  At node name: N10
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4578.464861'>
# >> Total branch lenght: 9.692778560000002
# >> PIP Likelihood: -4578.464861
# ++++++++++++++++++ Iteration 6,8 with remaining tree:
# --Sp006, 1.136e-05
#  At node name: Sp006
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4628.071058'>
# >> Total branch lenght: 9.692778559999999
# >> PIP Likelihood: -4628.071058
# ++++++++++++++++++ Iteration 6,9 with remaining tree:
#               /-Sp005, 0.158931
# -N12, 0.0757508
#               \-Sp007, 0.181737
#  At node name: N12
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4628.366740'>
# >> Total branch lenght: 9.692778560000002
# >> PIP Likelihood: -4628.366740
# ++++++++++++++++++ Iteration 6,10 with remaining tree:
# --Sp005, 0.158931
#  At node name: Sp005
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4629.280788'>
# >> Total branch lenght: 9.692778559999999
# >> PIP Likelihood: -4629.280788
# ++++++++++++++++++ Iteration 6,11 with remaining tree:
# --Sp007, 0.181737
#  At node name: Sp007
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4631.071724'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4631.071724
# ++++++++++++++++++ Iteration 7,0 with remaining tree:
#        /-Sp000, 4.10264
# -N1, 0.0
#       |             /-Sp003, 0.176516
#        \N4, 0.0238354
#                     \-Sp004, 2.351724
#  At node name: N1
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4602.722215'>
# >> Total branch lenght: 9.692774560000002
# >> PIP Likelihood: -4602.722215
# ++++++++++++++++++ Iteration 7,1 with remaining tree:
# --Sp002, 0.132302
#  At node name: Sp002
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4602.732823'>
# >> Total branch lenght: 9.69277456
# >> PIP Likelihood: -4602.732823
# ++++++++++++++++++ Iteration 7,2 with remaining tree:
# --Sp000, 4.10264
#  At node name: Sp000
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4604.143103'>
# >> Total branch lenght: 9.69277456
# >> PIP Likelihood: -4604.143103
# ++++++++++++++++++ Iteration 7,3 with remaining tree:
#              /-Sp003, 0.176516
# -N4, 0.0238354
#              \-Sp004, 2.351724
#  At node name: N4
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4603.038006'>
# >> Total branch lenght: 9.69277456
# >> PIP Likelihood: -4603.038006
# ++++++++++++++++++ Iteration 7,4 with remaining tree:
# --Sp003, 0.176516
#  At node name: Sp003
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4603.295913'>
# >> Total branch lenght: 9.69277456
# >> PIP Likelihood: -4603.295913
# ++++++++++++++++++ Iteration 7,5 with remaining tree:
# --Sp004, 2.351724
#  At node name: Sp004
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2809, 2842), match='Final LogLikelihood: -4578.124220'>
# >> Total branch lenght: 9.692774560000002
# >> PIP Likelihood: -4578.124220
# ++++++++++++++++++ Iteration 8,0 with remaining tree:
#        /-Sp000, 4.10264
# -N1, 0.0
#       |             /-Sp003, 0.176516
#        \N4, 0.0238354
#                    |            /-Sp004, 1.58237
#                     \N6, 0.769354
#                                |             /-Sp006, 1.136e-05
#                                 \N10, 2.342909
#                                             |              /-Sp005, 0.158931
#                                              \N12, 0.0757508
#                                                            \-Sp007, 0.181737
#  At node name: N1
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4614.974363'>
# >> Total branch lenght: 9.692779560000002
# >> PIP Likelihood: -4614.974363
# ++++++++++++++++++ Iteration 8,1 with remaining tree:
# --Sp002, 0.132302
#  At node name: Sp002
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4615.040126'>
# >> Total branch lenght: 9.692779560000002
# >> PIP Likelihood: -4615.040126
# ++++++++++++++++++ Iteration 8,2 with remaining tree:
# --Sp000, 4.10264
#  At node name: Sp000
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4616.279415'>
# >> Total branch lenght: 9.692779560000002
# >> PIP Likelihood: -4616.279415
# ++++++++++++++++++ Iteration 8,3 with remaining tree:
#              /-Sp003, 0.176516
# -N4, 0.0238354
#             |            /-Sp004, 1.58237
#              \N6, 0.769354
#                         |             /-Sp006, 1.136e-05
#                          \N10, 2.342909
#                                      |              /-Sp005, 0.158931
#                                       \N12, 0.0757508
#                                                     \-Sp007, 0.181737
#  At node name: N4
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4614.622909'>
# >> Total branch lenght: 9.692779560000002
# >> PIP Likelihood: -4614.622909
# ++++++++++++++++++ Iteration 8,4 with remaining tree:
# --Sp003, 0.176516
#  At node name: Sp003
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4615.140388'>
# >> Total branch lenght: 9.69277956
# >> PIP Likelihood: -4615.140388
# ++++++++++++++++++ Iteration 8,5 with remaining tree:
#             /-Sp004, 1.58237
# -N6, 0.769354
#            |             /-Sp006, 1.136e-05
#             \N10, 2.342909
#                         |              /-Sp005, 0.158931
#                          \N12, 0.0757508
#                                        \-Sp007, 0.181737
#  At node name: N6
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4578.336097'>
# >> Total branch lenght: 9.692779560000002
# >> PIP Likelihood: -4578.336097
# ++++++++++++++++++ Iteration 8,6 with remaining tree:
# --Sp004, 1.58237
#  At node name: Sp004
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4578.510007'>
# >> Total branch lenght: 9.692779560000002
# >> PIP Likelihood: -4578.510007
# ++++++++++++++++++ Iteration 8,7 with remaining tree:
#              /-Sp006, 1.136e-05
# -N10, 2.342909
#             |              /-Sp005, 0.158931
#              \N12, 0.0757508
#                            \-Sp007, 0.181737
#  At node name: N10
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4578.093830'>
# >> Total branch lenght: 9.692769560000002
# >> PIP Likelihood: -4578.093830
# ++++++++++++++++++ Iteration 8,8 with remaining tree:
# --Sp006, 1.136e-05
#  At node name: Sp006
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4674.394992'>
# >> Total branch lenght: 9.692779559999998
# >> PIP Likelihood: -4674.394992
# ++++++++++++++++++ Iteration 8,9 with remaining tree:
#               /-Sp005, 0.158931
# -N12, 0.0757508
#               \-Sp007, 0.181737
#  At node name: N12
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2815, 2848), match='Final LogLikelihood: -4674.824770'>
# >> Total branch lenght: 9.692779560000002
# >> PIP Likelihood: -4674.824770
# ++++++++++++++++++ Iteration 8,10 with remaining tree:
# --Sp005, 0.158931
#  At node name: Sp005
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2815, 2848), match='Final LogLikelihood: -4676.475441'>
# >> Total branch lenght: 9.692779559999998
# >> PIP Likelihood: -4676.475441
# ++++++++++++++++++ Iteration 8,11 with remaining tree:
# --Sp007, 0.181737
#  At node name: Sp007
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4676.381662'>
# >> Total branch lenght: 9.692779559999998
# >> PIP Likelihood: -4676.381662
# ++++++++++++++++++ Iteration 9,0 with remaining tree:
#        /-Sp000, 4.10264
# -N1, 0.0
#       |             /-Sp003, 0.176516
#        \N4, 0.0238354
#                    |            /-Sp004, 1.58237
#                     \N6, 0.769354
#                                 \-Sp001, 0.263611
#  At node name: N1
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2809, 2842), match='Final LogLikelihood: -4600.604736'>
# >> Total branch lenght: 9.692778559999999
# >> PIP Likelihood: -4600.604736
# ++++++++++++++++++ Iteration 9,1 with remaining tree:
# --Sp002, 0.132302
#  At node name: Sp002
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4600.222435'>
# >> Total branch lenght: 9.692778559999999
# >> PIP Likelihood: -4600.222435
# ++++++++++++++++++ Iteration 9,2 with remaining tree:
# --Sp000, 4.10264
#  At node name: Sp000
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2815, 2848), match='Final LogLikelihood: -4599.181120'>
# >> Total branch lenght: 9.692778559999999
# >> PIP Likelihood: -4599.181120
# ++++++++++++++++++ Iteration 9,3 with remaining tree:
#              /-Sp003, 0.176516
# -N4, 0.0238354
#             |            /-Sp004, 1.58237
#              \N6, 0.769354
#                          \-Sp001, 0.263611
#  At node name: N4
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4599.519190'>
# >> Total branch lenght: 9.692778559999999
# >> PIP Likelihood: -4599.519190
# ++++++++++++++++++ Iteration 9,4 with remaining tree:
# --Sp003, 0.176516
#  At node name: Sp003
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4599.937155'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4599.937155
# ++++++++++++++++++ Iteration 9,5 with remaining tree:
#             /-Sp004, 1.58237
# -N6, 0.769354
#             \-Sp001, 0.263611
#  At node name: N6
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4578.585801'>
# >> Total branch lenght: 9.69277856
# >> PIP Likelihood: -4578.585801
# ++++++++++++++++++ Iteration 9,6 with remaining tree:
# --Sp004, 1.58237
#  At node name: Sp004
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4578.699372'>
# >> Total branch lenght: 9.692778560000002
# >> PIP Likelihood: -4578.699372
# ++++++++++++++++++ Iteration 9,7 with remaining tree:
# --Sp001, 0.263611
#  At node name: Sp001
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4578.034299'>
# >> Total branch lenght: 9.692777560000001
# >> PIP Likelihood: -4578.034299
# ++++++++++++++++++ Iteration 10,0 with remaining tree:
#        /-Sp000, 4.10264
# -N1, 0.0
#       |             /-Sp003, 0.176516
#        \N4, 0.0238354
#                    |            /-Sp004, 1.58237
#                     \N6, 0.769354
#                                |            /-Sp001, 0.146422
#                                 \N8, 0.117189
#                                            |                       /-Sp005, 0.158931
#                                             \N12, 2.3014707999999997
#                                                                    \-Sp007, 0.181737
#  At node name: N1
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4981.886484'>
# >> Total branch lenght: 9.692777760000002
# >> PIP Likelihood: -4981.886484
# ++++++++++++++++++ Iteration 10,1 with remaining tree:
# --Sp002, 0.132302
#  At node name: Sp002
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4981.443517'>
# >> Total branch lenght: 9.692777760000002
# >> PIP Likelihood: -4981.443517
# ++++++++++++++++++ Iteration 10,2 with remaining tree:
# --Sp000, 4.10264
#  At node name: Sp000
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4983.376732'>
# >> Total branch lenght: 9.69277776
# >> PIP Likelihood: -4983.376732
# ++++++++++++++++++ Iteration 10,3 with remaining tree:
#              /-Sp003, 0.176516
# -N4, 0.0238354
#             |            /-Sp004, 1.58237
#              \N6, 0.769354
#                         |            /-Sp001, 0.146422
#                          \N8, 0.117189
#                                     |                       /-Sp005, 0.158931
#                                      \N12, 2.3014707999999997
#                                                             \-Sp007, 0.181737
#  At node name: N4
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4981.742027'>
# >> Total branch lenght: 9.692777760000002
# >> PIP Likelihood: -4981.742027
# ++++++++++++++++++ Iteration 10,4 with remaining tree:
# --Sp003, 0.176516
#  At node name: Sp003
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4981.648742'>
# >> Total branch lenght: 9.692777760000002
# >> PIP Likelihood: -4981.648742
# ++++++++++++++++++ Iteration 10,5 with remaining tree:
#             /-Sp004, 1.58237
# -N6, 0.769354
#            |            /-Sp001, 0.146422
#             \N8, 0.117189
#                        |                       /-Sp005, 0.158931
#                         \N12, 2.3014707999999997
#                                                \-Sp007, 0.181737
#  At node name: N6
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4688.903920'>
# >> Total branch lenght: 9.692777760000002
# >> PIP Likelihood: -4688.903920
# ++++++++++++++++++ Iteration 10,6 with remaining tree:
# --Sp004, 1.58237
#  At node name: Sp004
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4688.266283'>
# >> Total branch lenght: 9.692777760000002
# >> PIP Likelihood: -4688.266283
# ++++++++++++++++++ Iteration 10,7 with remaining tree:
#             /-Sp001, 0.146422
# -N8, 0.117189
#            |                       /-Sp005, 0.158931
#             \N12, 2.3014707999999997
#                                    \-Sp007, 0.181737
#  At node name: N8
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4674.901492'>
# >> Total branch lenght: 9.692777760000002
# >> PIP Likelihood: -4674.901492
# ++++++++++++++++++ Iteration 10,8 with remaining tree:
# --Sp001, 0.146422
#  At node name: Sp001
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2809, 2842), match='Final LogLikelihood: -4675.088681'>
# >> Total branch lenght: 9.692777760000004
# >> PIP Likelihood: -4675.088681
# ++++++++++++++++++ Iteration 10,9 with remaining tree:
#                        /-Sp005, 0.158931
# -N12, 2.3014707999999997
#                        \-Sp007, 0.181737
#  At node name: N12
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2815, 2848), match='Final LogLikelihood: -4578.165608'>
# >> Total branch lenght: 9.692787760000003
# >> PIP Likelihood: -4578.165608
# ++++++++++++++++++ Iteration 10,10 with remaining tree:
# --Sp005, 0.158931
#  At node name: Sp005
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4579.756554'>
# >> Total branch lenght: 9.69277776
# >> PIP Likelihood: -4579.756554
# ++++++++++++++++++ Iteration 10,11 with remaining tree:
# --Sp007, 0.181737
#  At node name: Sp007
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4579.711471'>
# >> Total branch lenght: 9.69277776
# >> PIP Likelihood: -4579.711471
# ++++++++++++++++++ Iteration 11,0 with remaining tree:
#        /-Sp000, 4.10264
# -N1, 0.0
#       |             /-Sp003, 0.176516
#        \N4, 0.0238354
#                    |            /-Sp004, 1.58237
#                     \N6, 0.769354
#                                |            /-Sp001, 0.146422
#                                 \N8, 0.117189
#                                             \-Sp006, 2.2257313599999997
#  At node name: N1
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4981.905023'>
# >> Total branch lenght: 9.6927772
# >> PIP Likelihood: -4981.905023
# ++++++++++++++++++ Iteration 11,1 with remaining tree:
# --Sp002, 0.132302
#  At node name: Sp002
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4980.402331'>
# >> Total branch lenght: 9.6927772
# >> PIP Likelihood: -4980.402331
# ++++++++++++++++++ Iteration 11,2 with remaining tree:
# --Sp000, 4.10264
#  At node name: Sp000
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4982.257092'>
# >> Total branch lenght: 9.6927772
# >> PIP Likelihood: -4982.257092
# ++++++++++++++++++ Iteration 11,3 with remaining tree:
#              /-Sp003, 0.176516
# -N4, 0.0238354
#             |            /-Sp004, 1.58237
#              \N6, 0.769354
#                         |            /-Sp001, 0.146422
#                          \N8, 0.117189
#                                      \-Sp006, 2.2257313599999997
#  At node name: N4
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4980.717909'>
# >> Total branch lenght: 9.6927772
# >> PIP Likelihood: -4980.717909
# ++++++++++++++++++ Iteration 11,4 with remaining tree:
# --Sp003, 0.176516
#  At node name: Sp003
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4980.255957'>
# >> Total branch lenght: 9.6927772
# >> PIP Likelihood: -4980.255957
# ++++++++++++++++++ Iteration 11,5 with remaining tree:
#             /-Sp004, 1.58237
# -N6, 0.769354
#            |            /-Sp001, 0.146422
#             \N8, 0.117189
#                         \-Sp006, 2.2257313599999997
#  At node name: N6
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4689.157243'>
# >> Total branch lenght: 9.6927772
# >> PIP Likelihood: -4689.157243
# ++++++++++++++++++ Iteration 11,6 with remaining tree:
# --Sp004, 1.58237
#  At node name: Sp004
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4688.967833'>
# >> Total branch lenght: 9.692777200000002
# >> PIP Likelihood: -4688.967833
# ++++++++++++++++++ Iteration 11,7 with remaining tree:
#             /-Sp001, 0.146422
# -N8, 0.117189
#             \-Sp006, 2.2257313599999997
#  At node name: N8
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4674.327220'>
# >> Total branch lenght: 9.6927772
# >> PIP Likelihood: -4674.327220
# ++++++++++++++++++ Iteration 11,8 with remaining tree:
# --Sp001, 0.146422
#  At node name: Sp001
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4674.370356'>
# >> Total branch lenght: 9.692777200000002
# >> PIP Likelihood: -4674.370356
# ++++++++++++++++++ Iteration 11,9 with remaining tree:
# --Sp006, 2.2257313599999997
#  At node name: Sp006
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4578.943709'>
# >> Total branch lenght: 9.692787200000001
# >> PIP Likelihood: -4578.943709
# ++++++++++++++++++ Iteration 12,0 with remaining tree:
#        /-Sp000, 4.10264
# -N1, 0.0
#       |             /-Sp003, 0.176516
#        \N4, 0.0238354
#                    |            /-Sp004, 1.58237
#                     \N6, 0.769354
#                                |            /-Sp001, 0.146422
#                                 \N8, 0.117189
#                                            |            /-Sp006, 1.136e-05
#                                             \N10, 2.22572
#                                                         \-Sp007, 0.2574878
#  At node name: N1
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4942.403050'>
# >> Total branch lenght: 9.692778760000001
# >> PIP Likelihood: -4942.403050
# ++++++++++++++++++ Iteration 12,1 with remaining tree:
# --Sp002, 0.132302
#  At node name: Sp002
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4941.887302'>
# >> Total branch lenght: 9.69277876
# >> PIP Likelihood: -4941.887302
# ++++++++++++++++++ Iteration 12,2 with remaining tree:
# --Sp000, 4.10264
#  At node name: Sp000
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2817, 2850), match='Final LogLikelihood: -4943.426200'>
# >> Total branch lenght: 9.69277876
# >> PIP Likelihood: -4943.426200
# ++++++++++++++++++ Iteration 12,3 with remaining tree:
#              /-Sp003, 0.176516
# -N4, 0.0238354
#             |            /-Sp004, 1.58237
#              \N6, 0.769354
#                         |            /-Sp001, 0.146422
#                          \N8, 0.117189
#                                     |            /-Sp006, 1.136e-05
#                                      \N10, 2.22572
#                                                  \-Sp007, 0.2574878
#  At node name: N4
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4941.505254'>
# >> Total branch lenght: 9.69277876
# >> PIP Likelihood: -4941.505254
# ++++++++++++++++++ Iteration 12,4 with remaining tree:
# --Sp003, 0.176516
#  At node name: Sp003
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4941.867561'>
# >> Total branch lenght: 9.69277876
# >> PIP Likelihood: -4941.867561
# ++++++++++++++++++ Iteration 12,5 with remaining tree:
#             /-Sp004, 1.58237
# -N6, 0.769354
#            |            /-Sp001, 0.146422
#             \N8, 0.117189
#                        |            /-Sp006, 1.136e-05
#                         \N10, 2.22572
#                                     \-Sp007, 0.2574878
#  At node name: N6
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4691.041637'>
# >> Total branch lenght: 9.692778760000001
# >> PIP Likelihood: -4691.041637
# ++++++++++++++++++ Iteration 12,6 with remaining tree:
# --Sp004, 1.58237
#  At node name: Sp004
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4690.005436'>
# >> Total branch lenght: 9.692778760000003
# >> PIP Likelihood: -4690.005436
# ++++++++++++++++++ Iteration 12,7 with remaining tree:
#             /-Sp001, 0.146422
# -N8, 0.117189
#            |            /-Sp006, 1.136e-05
#             \N10, 2.22572
#                         \-Sp007, 0.2574878
#  At node name: N8
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4679.237953'>
# >> Total branch lenght: 9.692778760000001
# >> PIP Likelihood: -4679.237953
# ++++++++++++++++++ Iteration 12,8 with remaining tree:
# --Sp001, 0.146422
#  At node name: Sp001
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4676.661136'>
# >> Total branch lenght: 9.692778760000003
# >> PIP Likelihood: -4676.661136
# ++++++++++++++++++ Iteration 12,9 with remaining tree:
#             /-Sp006, 1.136e-05
# -N10, 2.22572
#             \-Sp007, 0.2574878
#  At node name: N10
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4581.375363'>
# >> Total branch lenght: 9.692778760000001
# >> PIP Likelihood: -4581.375363
# ++++++++++++++++++ Iteration 12,10 with remaining tree:
# --Sp006, 1.136e-05
#  At node name: Sp006
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2809, 2842), match='Final LogLikelihood: -4579.168701'>
# >> Total branch lenght: 9.69277876
# >> PIP Likelihood: -4579.168701
# ++++++++++++++++++ Iteration 12,11 with remaining tree:
# --Sp007, 0.2574878
#  At node name: Sp007
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2817, 2850), match='Final LogLikelihood: -4578.032786'>
# >> Total branch lenght: 9.69277876
# >> PIP Likelihood: -4578.032786
# ++++++++++++++++++ Iteration 13,0 with remaining tree:
#        /-Sp000, 4.10264
# -N1, 0.0
#       |             /-Sp003, 0.176516
#        \N4, 0.0238354
#                    |            /-Sp004, 1.58237
#                     \N6, 0.769354
#                                |            /-Sp001, 0.146422
#                                 \N8, 0.117189
#                                            |            /-Sp006, 1.136e-05
#                                             \N10, 2.22572
#                                                         \-Sp005, 0.2346818
#  At node name: N1
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4923.904180'>
# >> Total branch lenght: 9.692778760000001
# >> PIP Likelihood: -4923.904180
# ++++++++++++++++++ Iteration 13,1 with remaining tree:
# --Sp002, 0.132302
#  At node name: Sp002
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2815, 2848), match='Final LogLikelihood: -4923.781150'>
# >> Total branch lenght: 9.69277876
# >> PIP Likelihood: -4923.781150
# ++++++++++++++++++ Iteration 13,2 with remaining tree:
# --Sp000, 4.10264
#  At node name: Sp000
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4925.130372'>
# >> Total branch lenght: 9.69277876
# >> PIP Likelihood: -4925.130372
# ++++++++++++++++++ Iteration 13,3 with remaining tree:
#              /-Sp003, 0.176516
# -N4, 0.0238354
#             |            /-Sp004, 1.58237
#              \N6, 0.769354
#                         |            /-Sp001, 0.146422
#                          \N8, 0.117189
#                                     |            /-Sp006, 1.136e-05
#                                      \N10, 2.22572
#                                                  \-Sp005, 0.2346818
#  At node name: N4
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4923.385867'>
# >> Total branch lenght: 9.69277876
# >> PIP Likelihood: -4923.385867
# ++++++++++++++++++ Iteration 13,4 with remaining tree:
# --Sp003, 0.176516
#  At node name: Sp003
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4923.631038'>
# >> Total branch lenght: 9.69277876
# >> PIP Likelihood: -4923.631038
# ++++++++++++++++++ Iteration 13,5 with remaining tree:
#             /-Sp004, 1.58237
# -N6, 0.769354
#            |            /-Sp001, 0.146422
#             \N8, 0.117189
#                        |            /-Sp006, 1.136e-05
#                         \N10, 2.22572
#                                     \-Sp005, 0.2346818
#  At node name: N6
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2815, 2848), match='Final LogLikelihood: -4691.162796'>
# >> Total branch lenght: 9.692778760000001
# >> PIP Likelihood: -4691.162796
# ++++++++++++++++++ Iteration 13,6 with remaining tree:
# --Sp004, 1.58237
#  At node name: Sp004
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4691.211168'>
# >> Total branch lenght: 9.692778760000001
# >> PIP Likelihood: -4691.211168
# ++++++++++++++++++ Iteration 13,7 with remaining tree:
#             /-Sp001, 0.146422
# -N8, 0.117189
#            |            /-Sp006, 1.136e-05
#             \N10, 2.22572
#                         \-Sp005, 0.2346818
#  At node name: N8
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2809, 2842), match='Final LogLikelihood: -4680.332847'>
# >> Total branch lenght: 9.692778760000001
# >> PIP Likelihood: -4680.332847
# ++++++++++++++++++ Iteration 13,8 with remaining tree:
# --Sp001, 0.146422
#  At node name: Sp001
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4676.658733'>
# >> Total branch lenght: 9.692778760000001
# >> PIP Likelihood: -4676.658733
# ++++++++++++++++++ Iteration 13,9 with remaining tree:
#             /-Sp006, 1.136e-05
# -N10, 2.22572
#             \-Sp005, 0.2346818
#  At node name: N10
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2813, 2846), match='Final LogLikelihood: -4582.821276'>
# >> Total branch lenght: 9.69277876
# >> PIP Likelihood: -4582.821276
# ++++++++++++++++++ Iteration 13,10 with remaining tree:
# --Sp006, 1.136e-05
#  At node name: Sp006
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2815, 2848), match='Final LogLikelihood: -4579.167397'>
# >> Total branch lenght: 9.692778759999998
# >> PIP Likelihood: -4579.167397
# ++++++++++++++++++ Iteration 13,11 with remaining tree:
# --Sp005, 0.2346818
#  At node name: Sp005
# ++++++++++++++++++
# GTR{0.31152/0.36752/0.36901/0.19015/1.12597/0.15899}+I{0.001}+G{0.672}+F{0.26592/0.14671/0.1774/0.40997}
# ll_re:  <re.Match object; span=(2811, 2844), match='Final LogLikelihood: -4578.034264'>
# >> Total branch lenght: 9.69277876
# >> PIP Likelihood: -4578.034264

# %%
from Utils import collect_features

collect_features.collect_features(CWD, tree_file, outpath_prune, outpath_rgft)
# Out:
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:134: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest"]] = features_dicts_dict["longest"]				#f3
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["top_dist"]] = features_dict_prune['top_dist'][prune_name][rgft_name]
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:119: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["bl_dist"]] = features_dict_prune['bl_dist'][prune_name][rgft_name]
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["res_bl"]] = res_bl
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, LABEL.format(move_type)] = d_ll  # LABEL
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["bl"]] = features_dicts_dict["bl"][edge] 					#f2
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:134: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest"]] = features_dicts_dict["longest"]				#f3
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["top_dist"]] = features_dict_prune['top_dist'][prune_name][rgft_name]
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:119: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["bl_dist"]] = features_dict_prune['bl_dist'][prune_name][rgft_name]
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["res_bl"]] = res_bl
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, LABEL.format(move_type)] = d_ll  # LABEL
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["bl"]] = features_dicts_dict["bl"][edge] 					#f2
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:134: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest"]] = features_dicts_dict["longest"]				#f3
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["top_dist"]] = features_dict_prune['top_dist'][prune_name][rgft_name]
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:119: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["bl_dist"]] = features_dict_prune['bl_dist'][prune_name][rgft_name]
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["res_bl"]] = res_bl
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, LABEL.format(move_type)] = d_ll  # LABEL
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["bl"]] = features_dicts_dict["bl"][edge] 					#f2
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:134: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest"]] = features_dicts_dict["longest"]				#f3
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, LABEL.format(move_type)] = d_ll  # LABEL
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["bl"]] = features_dicts_dict["bl"][edge] 					#f2
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:134: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest"]] = features_dicts_dict["longest"]				#f3
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["top_dist"]] = features_dict_prune['top_dist'][prune_name][rgft_name]
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:119: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["bl_dist"]] = features_dict_prune['bl_dist'][prune_name][rgft_name]
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["res_bl"]] = res_bl
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, LABEL.format(move_type)] = d_ll  # LABEL
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["bl"]] = features_dicts_dict["bl"][edge] 					#f2
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:134: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest"]] = features_dicts_dict["longest"]				#f3
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, LABEL.format(move_type)] = d_ll  # LABEL
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["bl"]] = features_dicts_dict["bl"][edge] 					#f2
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:134: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest"]] = features_dicts_dict["longest"]				#f3
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["top_dist"]] = features_dict_prune['top_dist'][prune_name][rgft_name]
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:119: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["bl_dist"]] = features_dict_prune['bl_dist'][prune_name][rgft_name]
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["res_bl"]] = res_bl
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, LABEL.format(move_type)] = d_ll  # LABEL
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["bl"]] = features_dicts_dict["bl"][edge] 					#f2
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:134: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest"]] = features_dicts_dict["longest"]				#f3
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, LABEL.format(move_type)] = d_ll  # LABEL
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["bl"]] = features_dicts_dict["bl"][edge] 					#f2
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:134: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest"]] = features_dicts_dict["longest"]				#f3
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["top_dist"]] = features_dict_prune['top_dist'][prune_name][rgft_name]
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:119: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["bl_dist"]] = features_dict_prune['bl_dist'][prune_name][rgft_name]
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["res_bl"]] = res_bl
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, LABEL.format(move_type)] = d_ll  # LABEL
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["bl"]] = features_dicts_dict["bl"][edge] 					#f2
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:134: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest"]] = features_dicts_dict["longest"]				#f3
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# ...
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, LABEL.format(move_type)] = d_ll  # LABEL
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["bl"]] = features_dicts_dict["bl"][edge] 					#f2
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:134: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest"]] = features_dicts_dict["longest"]				#f3
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["top_dist"]] = features_dict_prune['top_dist'][prune_name][rgft_name]
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:119: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["bl_dist"]] = features_dict_prune['bl_dist'][prune_name][rgft_name]
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["res_bl"]] = res_bl
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, LABEL.format(move_type)] = d_ll  # LABEL
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["bl"]] = features_dicts_dict["bl"][edge] 					#f2
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:134: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest"]] = features_dicts_dict["longest"]				#f3
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:130: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, LABEL.format(move_type)] = d_ll  # LABEL
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:133: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["bl"]] = features_dicts_dict["bl"][edge] 					#f2
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:134: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest"]] = features_dicts_dict["longest"]				#f3
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["ntaxa_{}".format(subtype)]] = features_dicts_dict["ntaxa_{}".format(subtype)][edge]  		#f4,5
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["tbl_{}".format(subtype)]] = features_dicts_dict["tbl_{}".format(subtype)][edge]  			#f6,7
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:140: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dff[ind, FEATURES["longest_{}".format(subtype)]] = features_dicts_dict["longest_{}".format(subtype)][edge]	#f8,9
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:118: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["top_dist"]] = features_dict_prune['top_dist'][prune_name][rgft_name]
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:119: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["bl_dist"]] = features_dict_prune['bl_dist'][prune_name][rgft_name]
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/Utils/collect_features.py:120: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_rgft[ind, FEATURES["res_bl"]] = res_bl

# %%
import os
from Utils.defs_PhyAI import DATA_WITH_PREDS, FEATURES_SHARED, FEATURES, LABEL, SCORES_PER_DS, types_dict, FEATURES_RGFT_ONLY, FEATURES_MERGED, FEATURES_RGFT, FEATURES_PRUNE, GROUP_ID
from Utils import RF_learning_algorithm

# %%
import numpy as np
from Utils.tree_functions import get_total_branch_lengths
from Utils.defs_PhyAI import PHYML_TREE_FILENAME, SUMMARY_PER_DS

def parse_relevant_summaries_for_learning(datapath, outpath, move_type, step_number, tree_type='bionj'):

	for i,relpath in enumerate(os.listdir(datapath)):
		if i ==0:
			ds_path_init = datapath+relpath
			cols = list(pd.read_csv(SUMMARY_PER_DS.format(datapath, move_type)))
			cols.insert(1, "path")
			cols.extend([FEATURES[GROUP_ID], FEATURES["group_tbl"]])
			df = pd.DataFrame(index=np.arange(0), columns=cols)
			
		ds_path = datapath + relpath
		ds_tbl = get_total_branch_lengths(tree_file)
		summary_per_ds = SUMMARY_PER_DS.format(datapath, move_type)
		
		if os.path.exists(summary_per_ds) and FEATURES["bl"] in pd.read_csv(summary_per_ds).columns:
			df_ds = pd.read_csv(summary_per_ds)
			df_ds.insert(1, "path", datapath)
			df_ds[FEATURES[GROUP_ID]] = str(i)
			df_ds[FEATURES["group_tbl"]] = ds_tbl
			df = pd.concat([df, df_ds], ignore_index=True)
	
	df.to_csv(outpath)

# %%
move_type, st = "merged", "1"
transform_target, validation_set = False, False
#print(CWD)
df_path = TEST_DATA_PATH + LEARNING_DATA.format("all_moves")
#print(df_path)
df_prune_features = TEST_DATA_PATH + LEARNING_DATA.format("all_moves_prune")
#print(df_prune_features)
df_rgft_features = TEST_DATA_PATH + LEARNING_DATA.format("all_moves_rgft")
#print(df_rgft_features)

if not os.path.exists(df_path):
	parse_relevant_summaries_for_learning(CWD, df_prune_features, "prune", st,)
	parse_relevant_summaries_for_learning(CWD, df_rgft_features, "rgft", st)
	shared_cols = FEATURES_SHARED + ["path","prune_name","rgft_name","orig_ds_ll", "ll"]
	df_prune_moves = pd.read_csv(df_prune_features, dtype=types_dict)
	print(df_prune_moves.head())
	df_rgft_moves = pd.read_csv(df_rgft_features, dtype=types_dict)
	print(df_rgft_moves.head(5))
	complete_df = pd.merge(df_prune_moves, df_rgft_moves, on=shared_cols, left_index=True, right_index=True, suffixes=('_prune', '_rgft'))
 
	complete_df = complete_df.rename(columns={FEATURES[f]: FEATURES[f] + "_rgft" for f in FEATURES_RGFT_ONLY})
	complete_df[LABEL.format(move_type)] = complete_df[LABEL.format("prune")]
	complete_df.to_csv(df_path)

df_learning = pd.read_csv(df_path, dtype=types_dict)
df_learning = RF_learning_algorithm.fit_transformation(df_learning, move_type, trans=transform_target)

features = FEATURES_PRUNE if move_type == "prune" else FEATURES_RGFT if move_type == "rgft" else FEATURES_MERGED
features.remove(FEATURES[GROUP_ID])

########################

suf = "_{}_validation_set".format(st) if validation_set else "_{}".format(st)
iftrans = "" if not transform_target else "_ytransformed"
suf += iftrans
csv_with_scores = CWD + SCORES_PER_DS.format(str(len(features))+ suf)
csv_with_preds = CWD + DATA_WITH_PREDS.format(str(len(features)) + suf)
if not os.path.exists(csv_with_scores) or validation_set:
	print("*@*@*@* scores for step{} with {} features are not available, thus applying learning".format(suf, len(features)))
	res_dict, df_out = RF_learning_algorithm.cross_validation_RF(df_learning, move_type, features, trans=transform_target ,validation_set=validation_set)
	df_out.to_csv(csv_with_preds)

	df_datasets =  pd.DataFrame(columns=["init"])
else:
	df_datasets = pd.read_csv(csv_with_scores)
	res_dict = RF_learning_algorithm.extract_scores_dict({}, df_datasets)
df_datasets = RF_learning_algorithm.print_and_index_results(df_datasets, res_dict, features)
df_datasets.to_csv(csv_with_scores)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, path, orig_ds_ll, prune_name, rgft_name, time, ll, ('2,0', 'd_ll_prune'), ('2,0', 'edge_length'), ('2,0', 'longest_branch'), ('2,0', 'name2ntaxa_pruned'), ('2,0', 'tbl_pruned'), ('2,0', 'longest_pruned'), ('2,0', 'name2ntaxa_remaining'), ('2,0', 'tbl_remaining'), ('2,0', 'longest_remaining'), ('2,1', 'd_ll_prune'), ('2,1', 'edge_length'), ('2,1', 'longest_branch'), ('2,1', 'name2ntaxa_pruned'), ('2,1', 'tbl_pruned'), ('2,1', 'longest_pruned'), ('2,1', 'name2ntaxa_remaining'), ('2,1', 'tbl_remaining'), ('2,1', 'longest_remaining'), ('2,2', 'd_ll_prune'), ('2,2', 'edge_length'), ('2,2', 'longest_branch'), ('2,2', 'name2ntaxa_pruned'), ('2,2', 'tbl_pruned'), ('2,2', 'longest_pruned'), ('2,2', 'name2ntaxa_remaining'), ('2,2', 'tbl_remaining'), ('2,2', 'longest_remaining'), ('2,3', 'd_ll_prune'), ('2,3', 'edge_length'), ('2,3', 'longest_branch'), ('2,3', 'name2ntaxa_pruned'), ('2,3', 'tbl_pruned'), ('2,3', 'longest_pruned'), ('2,3', 'name2ntaxa_remaining'), ('2,3', 'tbl_remaining'), ('2,3', 'longest_remaining'), ('2,4', 'd_ll_prune'), ('2,4', 'edge_length'), ('2,4', 'longest_branch'), ('2,4', 'name2ntaxa_pruned'), ('2,4', 'tbl_pruned'), ('2,4', 'longest_pruned'), ('2,4', 'name2ntaxa_remaining'), ('2,4', 'tbl_remaining'), ('2,4', 'longest_remaining'), ('2,5', 'd_ll_prune'), ('2,5', 'edge_length'), ('2,5', 'longest_branch'), ('2,5', 'name2ntaxa_pruned'), ('2,5', 'tbl_pruned'), ('2,5', 'longest_pruned'), ('2,5', 'name2ntaxa_remaining'), ('2,5', 'tbl_remaining'), ('2,5', 'longest_remaining'), ('2,6', 'd_ll_prune'), ('2,6', 'edge_length'), ('2,6', 'longest_branch'), ('2,6', 'name2ntaxa_pruned'), ('2,6', 'tbl_pruned'), ('2,6', 'longest_pruned'), ('2,6', 'name2ntaxa_remaining'), ('2,6', 'tbl_remaining'), ('2,6', 'longest_remaining'), ('2,7', 'd_ll_prune'), ('2,7', 'edge_length'), ('2,7', 'longest_branch'), ('2,7', 'name2ntaxa_pruned'), ('2,7', 'tbl_pruned'), ('2,7', 'longest_pruned'), ('2,7', 'name2ntaxa_remaining'), ('2,7', 'tbl_remaining'), ('2,7', 'longest_remaining'), ('2,8', 'd_ll_prune'), ('2,8', 'edge_length'), ('2,8', 'longest_branch'), ('2,8', 'name2ntaxa_pruned'), ('2,8', 'tbl_pruned'), ('2,8', 'longest_pruned'), ('2,8', 'name2ntaxa_remaining'), ('2,8', 'tbl_remaining'), ('2,8', 'longest_remaining'), ('2,9', 'd_ll_prune'), ('2,9', 'edge_length'), ('2,9', 'longest_branch'), ('2,9', 'name2ntaxa_pruned'), ('2,9', 'tbl_pruned'), ('2,9', 'longest_pruned'), ('2,9', 'name2ntaxa_remaining'), ('2,9', 'tbl_remaining'), ('2,9', 'longest_remaining'), ('2,10', 'd_ll_prune'), ('2,10', 'edge_length'), ...]
# Index: []
#
# [0 rows x 1036 columns]
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, path, orig_ds_ll, prune_name, rgft_name, time, ll, ('2,0', 'd_ll_rgft'), ('2,0', 'edge_length'), ('2,0', 'longest_branch'), ('2,0', 'name2ntaxa_pruned'), ('2,0', 'tbl_pruned'), ('2,0', 'longest_pruned'), ('2,0', 'name2ntaxa_remaining'), ('2,0', 'tbl_remaining'), ('2,0', 'longest_remaining'), ('2,0', 'topology_dist_between'), ('2,0', 'tbl_dist_between'), ('2,0', 'res_tree_edge_length'), ('2,1', 'd_ll_rgft'), ('2,1', 'edge_length'), ('2,1', 'longest_branch'), ('2,1', 'name2ntaxa_pruned'), ('2,1', 'tbl_pruned'), ('2,1', 'longest_pruned'), ('2,1', 'name2ntaxa_remaining'), ('2,1', 'tbl_remaining'), ('2,1', 'longest_remaining'), ('2,1', 'topology_dist_between'), ('2,1', 'tbl_dist_between'), ('2,1', 'res_tree_edge_length'), ('2,2', 'd_ll_rgft'), ('2,2', 'edge_length'), ('2,2', 'longest_branch'), ('2,2', 'name2ntaxa_pruned'), ('2,2', 'tbl_pruned'), ('2,2', 'longest_pruned'), ('2,2', 'name2ntaxa_remaining'), ('2,2', 'tbl_remaining'), ('2,2', 'longest_remaining'), ('2,2', 'topology_dist_between'), ('2,2', 'tbl_dist_between'), ('2,2', 'res_tree_edge_length'), ('2,3', 'd_ll_rgft'), ('2,3', 'edge_length'), ('2,3', 'longest_branch'), ('2,3', 'name2ntaxa_pruned'), ('2,3', 'tbl_pruned'), ('2,3', 'longest_pruned'), ('2,3', 'name2ntaxa_remaining'), ('2,3', 'tbl_remaining'), ('2,3', 'longest_remaining'), ('2,3', 'topology_dist_between'), ('2,3', 'tbl_dist_between'), ('2,3', 'res_tree_edge_length'), ('2,4', 'd_ll_rgft'), ('2,4', 'edge_length'), ('2,4', 'longest_branch'), ('2,4', 'name2ntaxa_pruned'), ('2,4', 'tbl_pruned'), ('2,4', 'longest_pruned'), ('2,4', 'name2ntaxa_remaining'), ('2,4', 'tbl_remaining'), ('2,4', 'longest_remaining'), ('2,4', 'topology_dist_between'), ('2,4', 'tbl_dist_between'), ('2,4', 'res_tree_edge_length'), ('2,5', 'd_ll_rgft'), ('2,5', 'edge_length'), ('2,5', 'longest_branch'), ('2,5', 'name2ntaxa_pruned'), ('2,5', 'tbl_pruned'), ('2,5', 'longest_pruned'), ('2,5', 'name2ntaxa_remaining'), ('2,5', 'tbl_remaining'), ('2,5', 'longest_remaining'), ('2,5', 'topology_dist_between'), ('2,5', 'tbl_dist_between'), ('2,5', 'res_tree_edge_length'), ('2,6', 'd_ll_rgft'), ('2,6', 'edge_length'), ('2,6', 'longest_branch'), ('2,6', 'name2ntaxa_pruned'), ('2,6', 'tbl_pruned'), ('2,6', 'longest_pruned'), ('2,6', 'name2ntaxa_remaining'), ('2,6', 'tbl_remaining'), ('2,6', 'longest_remaining'), ('2,6', 'topology_dist_between'), ('2,6', 'tbl_dist_between'), ('2,6', 'res_tree_edge_length'), ('2,7', 'd_ll_rgft'), ('2,7', 'edge_length'), ('2,7', 'longest_branch'), ('2,7', 'name2ntaxa_pruned'), ('2,7', 'tbl_pruned'), ('2,7', 'longest_pruned'), ('2,7', 'name2ntaxa_remaining'), ('2,7', 'tbl_remaining'), ...]
# Index: []
#
# [0 rows x 1378 columns]
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# /Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/sequence.ipynb Cell 9 line <cell line: 11>()
#      <a href='vscode-notebook-cell:/Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/sequence.ipynb#X11sZmlsZQ%3D%3D?line=16'>17</a> df_rgft_moves = pd.read_csv(df_rgft_features, dtype=types_dict)
#      <a href='vscode-notebook-cell:/Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/sequence.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a> print(df_rgft_moves.head(5))
# ---> <a href='vscode-notebook-cell:/Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/sequence.ipynb#X11sZmlsZQ%3D%3D?line=18'>19</a> complete_df = pd.merge(df_prune_moves, df_rgft_moves, on=shared_cols, left_index=True, right_index=True, suffixes=('_prune', '_rgft'))
#      <a href='vscode-notebook-cell:/Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/sequence.ipynb#X11sZmlsZQ%3D%3D?line=20'>21</a> complete_df = complete_df.rename(columns={FEATURES[f]: FEATURES[f] + "_rgft" for f in FEATURES_RGFT_ONLY})
#      <a href='vscode-notebook-cell:/Users/mihaid/Coding-Projects/thesis/DL_Phylo_Opt/sequence.ipynb#X11sZmlsZQ%3D%3D?line=21'>22</a> complete_df[LABEL.format(move_type)] = complete_df[LABEL.format("prune")]
#
# File ~/opt/anaconda3/envs/phytree/lib/python3.9/site-packages/pandas/core/reshape/merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File ~/opt/anaconda3/envs/phytree/lib/python3.9/site-packages/pandas/core/reshape/merge.py:682, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     678     # stacklevel chosen to be correct when this is reached via pd.merge
#     679     # (and not DataFrame.join)
#     680     warnings.warn(msg, FutureWarning, stacklevel=find_stack_level())
# --> 682 self._validate_specification()
#     684 cross_col = None
#     685 if self.how == "cross":
#
# File ~/opt/anaconda3/envs/phytree/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1373, in _MergeOperation._validate_specification(self)
#    1368         raise MergeError(
#    1369             'Can only pass argument "on" OR "left_on" '
#    1370             'and "right_on", not a combination of both.'
#    1371         )
#    1372     if self.left_index or self.right_index:
# -> 1373         raise MergeError(
#    1374             'Can only pass argument "on" OR "left_index" '
#    1375             'and "right_index", not a combination of both.'
#    1376         )
#    1377     self.left_on = self.right_on = self.on
#    1378 elif self.left_on is not None:
#
# MergeError: Can only pass argument "on" OR "left_index" and "right_index", not a combination of both.
